# %% [markdown]
# # Phase 3: 歯科ドメイン適応学習 (Stage 3a + Stage 3b / BiomedCLIP)
#
# **目的**: PatchAlign3D を歯科点群データ (normPLYs + candidates.json) でファインチューニングし、
# 解剖学的パッチ‑テキスト対応を学習させる。
#
# **テキストエンコーダ**: BiomedCLIP (`hf-hub:microsoft/BiomedCLIP-PubMedBERT_256-vit_base_patch16_224`)
# **テキスト出力次元**: **512** (ViT-bigG-14 の 1280 から変更)
#
# ---
# **チェックリスト**
# ```
# [ ] Google Drive マウント
# [ ] GPU / CUDA 確認
# [ ] 必要パッケージのインストール確認
# [ ] pointnet2_ops / KNN_CUDA ビルド成功
# [ ] BiomedCLIP ロード確認 (テキスト次元 512)
# [ ] PatchAlign3D パッケージ install 成功
# [ ] HF チェックポイント (patchalign3d.pt) ダウンロード完了
# [ ] データセット検証: 20 PLY + candidates.json 整合性確認
# [ ] Stage 3a 学習完了
# [ ] Stage 3b 学習完了
# [ ] stage3b_best.pt 保存確認
# ```

# %% [markdown]
# ## Step 0 — Google Drive マウント & パス設定

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys, os

# ===== パス設定 =====
DRIVE_ROOT   = '/content/drive/MyDrive'
REPO_ROOT    = f'{DRIVE_ROOT}/2026研究/ULIP_PointLLM'
PA3D_REF     = f'{REPO_ROOT}/_reference_repos/PatchAlign3D'
PHASE3_DIR   = f'{REPO_ROOT}/DentalPatchAligned3D/Phase3_Training_v2'
CKPT_DIR     = f'{REPO_ROOT}/checkpoints/patchalign3d'

# データパス
PLY_DIR      = f'{DRIVE_ROOT}/2026研究/Dataset/6167726/STLs/STLs/normPLYs'
JSON_PATH    = f'{REPO_ROOT}/data/DentalPatchData/dental_vocab/candidates.json'

# 出力ディレクトリ
OUT_3A       = f'{PHASE3_DIR}/outputs/stage3a'
OUT_3B       = f'{PHASE3_DIR}/outputs/stage3b'

for d in [CKPT_DIR, OUT_3A, OUT_3B]:
    os.makedirs(d, exist_ok=True)

print(f'REPO_ROOT  : {REPO_ROOT}')
print(f'PHASE3_DIR : {PHASE3_DIR}')
print(f'PLY_DIR    : {PLY_DIR}')
print(f'JSON_PATH  : {JSON_PATH}')
print(f'CKPT_DIR   : {CKPT_DIR}')
# Out:
# REPO_ROOT  : /content/drive/MyDrive/2026研究/ULIP_PointLLM
# PHASE3_DIR : /content/drive/MyDrive/2026研究/ULIP_PointLLM/DentalPatchAligned3D/Phase3_Training_v2
# PLY_DIR    : /content/drive/MyDrive/2026研究/Dataset/6167726/STLs/STLs/normPLYs
# JSON_PATH  : /content/drive/MyDrive/2026研究/ULIP_PointLLM/data/DentalPatchData/dental_vocab/candidates.json
# CKPT_DIR   : /content/drive/MyDrive/2026研究/ULIP_PointLLM/checkpoints/patchalign3d

# %% [markdown]
# ## Step 1 — GPU / CUDA 確認

# %%
import torch

device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f'device      : {device}')
print(f'torch       : {torch.__version__}')

if device == 'cuda':
    print(f'GPU         : {torch.cuda.get_device_name(0)}')
    print(f'VRAM        : {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB')
    print(f'CUDA        : {torch.version.cuda}')
else:
    print('WARNING: GPU が利用できません。ランタイムを「GPU」に変更してください。')
# Out:
# device      : cuda
# torch       : 2.10.0+cu128
# GPU         : NVIDIA A100-SXM4-40GB
# VRAM        : 42.4 GB
# CUDA        : 12.8

# %% [markdown]
# ## Step 2 — パッケージインストール
#
# > **Colab 注意事項**
# > - `torch`, `torchvision`, `numpy`, `Pillow` は Colab に既インストール済みのため **再インストール不要**
# > - `open3d==0.17.0` は Python 3.12 に対応していないため **バージョン指定なし** でインストール
# > - `wandb` は学習時のみ必要なため、使わない場合は **スキップ可**

# %%
# 既インストール済みパッケージの確認
import importlib

PREINSTALLED = ['torch', 'torchvision', 'numpy', 'PIL', 'tqdm']
NEED_INSTALL  = ['open_clip', 'timm', 'easydict', 'termcolor', 'open3d', 'ninja',
                 'huggingface_hub', 'plyfile', 'yaml']

print('=== 既インストール確認 ===')
for pkg in PREINSTALLED:
    try:
        mod = importlib.import_module(pkg)
        ver = getattr(mod, '__version__', 'unknown')
        print(f'  [OK] {pkg} {ver}')
    except ImportError:
        print(f'  [NG] {pkg} — 要インストール')

print('\n=== 追加インストール要否 ===')
for pkg in NEED_INSTALL:
    try:
        mod = importlib.import_module(pkg)
        ver = getattr(mod, '__version__', 'unknown')
        print(f'  [OK] {pkg} {ver}')
    except ImportError:
        print(f'  [要] {pkg}')
# Out:
# === 既インストール確認 ===
#   [OK] torch 2.10.0+cu128
#   [OK] torchvision 0.25.0+cu128
#   [OK] numpy 2.0.2
#   [OK] PIL 11.3.0
#   [OK] tqdm 4.67.3
#
# === 追加インストール要否 ===
#   [要] open_clip
#   [OK] timm 1.0.26
#   [OK] easydict unknown
#   [OK] termcolor unknown
#   [要] open3d
#   [要] ninja
#   [OK] huggingface_hub 1.10.1
#   [要] plyfile
#   [OK] yaml 6.0.3

# %%
# ===== 追加パッケージのインストール =====
# !pip install open_clip_torch>=2.24.0 timm easydict termcolor ninja open3d plyfile pyyaml -q

import open_clip, timm, easydict, termcolor, open3d, plyfile
print(f'open_clip : {open_clip.__version__}')
print(f'timm      : {timm.__version__}')
print(f'open3d    : {open3d.__version__}')
print(f'plyfile   : {getattr(plyfile, "__version__", "installed (no __version__)")}')
print('追加パッケージ OK')
# Out:
# open_clip : 3.3.0
# timm      : 1.0.26
# open3d    : 0.19.0
# plyfile   : installed (no __version__)
# 追加パッケージ OK

# %% [markdown]
# ## Step 3 — pointnet2_ops / KNN_CUDA のインストール
#
# > `ninja` が必要（Step 2 でインストール済み）
# > Colab の CUDA バージョンに自動対応

# %%
import os, torch, shutil

# 1. 環境リセット
# %cd /content
if os.path.exists('/tmp/Pointnet2_PyTorch'):
    shutil.rmtree('/tmp/Pointnet2_PyTorch')

# !git clone --quiet --depth 1 https://github.com/erikwijmans/Pointnet2_PyTorch.git /tmp/Pointnet2_PyTorch

# 2. ソースコードのパッチ (AT_CHECK 置換 & THC 除去)
# CUDA 12 系でコンパイルエラーを回避するため必須
# !find /tmp/Pointnet2_PyTorch/pointnet2_ops_lib/pointnet2_ops/_ext-src/src -type f -exec sed -i 's/AT_CHECK/TORCH_CHECK/g' {} +
# !find /tmp/Pointnet2_PyTorch/pointnet2_ops_lib/pointnet2_ops/_ext-src/src -type f -exec sed -i '/#include <THC\/THC.h>/d' {} +

# 3. setup.py の CUDA アーキテクチャを現在の GPU に合わせる
major, minor = torch.cuda.get_device_capability()
new_arch = f'{major}.{minor}'
SETUP_PY = '/tmp/Pointnet2_PyTorch/pointnet2_ops_lib/setup.py'
# !sed -i 's/os.environ\["TORCH_CUDA_ARCH_LIST"\] = .*/os.environ["TORCH_CUDA_ARCH_LIST"] = "{new_arch}"/g' {SETUP_PY}
print(f'setup.py patched: TORCH_CUDA_ARCH_LIST = {new_arch}')

# 4. インストール
# %cd /tmp/Pointnet2_PyTorch/pointnet2_ops_lib
# !pip -v install .

# 5. 確認
# %cd /content
try:
    from pointnet2_ops import pointnet2_utils
    print('pointnet2_ops: インストール成功')
except Exception as e:
    print(f'pointnet2_ops: 失敗 → {e}')
# Out:
# /content
# setup.py patched: TORCH_CUDA_ARCH_LIST = 8.0
# /tmp/Pointnet2_PyTorch/pointnet2_ops_lib
# Using pip 24.1.2 from /usr/local/lib/python3.12/dist-packages/pip (python 3.12)
# Processing /tmp/Pointnet2_PyTorch/pointnet2_ops_lib
#   Running command python setup.py egg_info
#   running egg_info
#   creating /tmp/pip-pip-egg-info-fa3ageft/pointnet2_ops.egg-info
#   writing /tmp/pip-pip-egg-info-fa3ageft/pointnet2_ops.egg-info/PKG-INFO
#   writing dependency_links to /tmp/pip-pip-egg-info-fa3ageft/pointnet2_ops.egg-info/dependency_links.txt
#   writing requirements to /tmp/pip-pip-egg-info-fa3ageft/pointnet2_ops.egg-info/requires.txt
#   writing top-level names to /tmp/pip-pip-egg-info-fa3ageft/pointnet2_ops.egg-info/top_level.txt
#   writing manifest file '/tmp/pip-pip-egg-info-fa3ageft/pointnet2_ops.egg-info/SOURCES.txt'
#   reading manifest file '/tmp/pip-pip-egg-info-fa3ageft/pointnet2_ops.egg-info/SOURCES.txt'
#   reading manifest template 'MANIFEST.in'
#   writing manifest file '/tmp/pip-pip-egg-info-fa3ageft/pointnet2_ops.egg-info/SOURCES.txt'
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch>=1.4 in /usr/local/lib/python3.12/dist-packages (from pointnet2_ops==3.0.0) (2.10.0+cu128)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->pointnet2_ops==3.0.0) (3.25.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->pointnet2_ops==3.0.0) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->pointnet2_ops==3.0.0) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->pointnet2_ops==3.0.0) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->pointnet2_ops==3.0.0) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->pointnet2_ops==3.0.0) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->pointnet2_ops==3.0.0) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->pointnet2_ops==3.0.0) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->pointnet2_ops==3.0.0) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->pointnet2_ops==3.0.0) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->pointnet2_ops==3.0.0) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->pointnet2_ops==3.0.0) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->pointnet2_ops==3.0.0) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->pointnet2_ops==3.0.0) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->pointnet2_ops==3.0.0) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->pointnet2_ops==3.0.0) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->pointnet2_ops==3.0.0) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->pointnet2_ops==3.0.0) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->pointnet2_ops==3.0.0) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->pointnet2_ops==3.0.0) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->pointnet2_ops==3.0.0) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->pointnet2_ops==3.0.0) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->pointnet2_ops==3.0.0) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4->pointnet2_ops==3.0.0) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=1.4->pointnet2_ops==3.0.0) (1.5.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.4->pointnet2_ops==3.0.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.4->pointnet2_ops==3.0.0) (3.0.3)
# Building wheels for collected packages: pointnet2_ops
#   Running command python setup.py bdist_wheel
#   running bdist_wheel
#   running build
#   running build_py
#   creating build/lib.linux-x86_64-cpython-312/pointnet2_ops
#   copying pointnet2_ops/pointnet2_utils.py -> build/lib.linux-x86_64-cpython-312/pointnet2_ops
#   copying pointnet2_ops/pointnet2_modules.py -> build/lib.linux-x86_64-cpython-312/pointnet2_ops
#   copying pointnet2_ops/__init__.py -> build/lib.linux-x86_64-cpython-312/pointnet2_ops
#   copying pointnet2_ops/_version.py -> build/lib.linux-x86_64-cpython-312/pointnet2_ops
#   running egg_info
#   creating pointnet2_ops.egg-info
#   writing pointnet2_ops.egg-info/PKG-INFO
#   writing dependency_links to pointnet2_ops.egg-info/dependency_links.txt
#   writing requirements to pointnet2_ops.egg-info/requires.txt
#   writing top-level names to pointnet2_ops.egg-info/top_level.txt
#   writing manifest file 'pointnet2_ops.egg-info/SOURCES.txt'
#   reading manifest file 'pointnet2_ops.egg-info/SOURCES.txt'
#   reading manifest template 'MANIFEST.in'
#   writing manifest file 'pointnet2_ops.egg-info/SOURCES.txt'
#   creating build/lib.linux-x86_64-cpython-312/pointnet2_ops/_ext-src/include
#   copying pointnet2_ops/_ext-src/include/ball_query.h -> build/lib.linux-x86_64-cpython-312/pointnet2_ops/_ext-src/include
#   copying pointnet2_ops/_ext-src/include/cuda_utils.h -> build/lib.linux-x86_64-cpython-312/pointnet2_ops/_ext-src/include
#   copying pointnet2_ops/_ext-src/include/group_points.h -> build/lib.linux-x86_64-cpython-312/pointnet2_ops/_ext-src/include
#   copying pointnet2_ops/_ext-src/include/interpolate.h -> build/lib.linux-x86_64-cpython-312/pointnet2_ops/_ext-src/include
#   copying pointnet2_ops/_ext-src/include/sampling.h -> build/lib.linux-x86_64-cpython-312/pointnet2_ops/_ext-src/include
#   copying pointnet2_ops/_ext-src/include/utils.h -> build/lib.linux-x86_64-cpython-312/pointnet2_ops/_ext-src/include
#   creating build/lib.linux-x86_64-cpython-312/pointnet2_ops/_ext-src/src
#   copying pointnet2_ops/_ext-src/src/ball_query.cpp -> build/lib.linux-x86_64-cpython-312/pointnet2_ops/_ext-src/src
#   copying pointnet2_ops/_ext-src/src/ball_query_gpu.cu -> build/lib.linux-x86_64-cpython-312/pointnet2_ops/_ext-src/src
#   copying pointnet2_ops/_ext-src/src/bindings.cpp -> build/lib.linux-x86_64-cpython-312/pointnet2_ops/_ext-src/src
#   copying pointnet2_ops/_ext-src/src/group_points.cpp -> build/lib.linux-x86_64-cpython-312/pointnet2_ops/_ext-src/src
#   copying pointnet2_ops/_ext-src/src/group_points_gpu.cu -> build/lib.linux-x86_64-cpython-312/pointnet2_ops/_ext-src/src
#   copying pointnet2_ops/_ext-src/src/interpolate.cpp -> build/lib.linux-x86_64-cpython-312/pointnet2_ops/_ext-src/src
#   copying pointnet2_ops/_ext-src/src/interpolate_gpu.cu -> build/lib.linux-x86_64-cpython-312/pointnet2_ops/_ext-src/src
#   copying pointnet2_ops/_ext-src/src/sampling.cpp -> build/lib.linux-x86_64-cpython-312/pointnet2_ops/_ext-src/src
#   copying pointnet2_ops/_ext-src/src/sampling_gpu.cu -> build/lib.linux-x86_64-cpython-312/pointnet2_ops/_ext-src/src
#   running build_ext
#   W0421 11:51:54.376000 1987 torch/utils/cpp_extension.py:535] There are no x86_64-linux-gnu-g++ version bounds defined for CUDA version 12.8
#   building 'pointnet2_ops._ext' extension
#   creating /tmp/Pointnet2_PyTorch/pointnet2_ops_lib/build/temp.linux-x86_64-cpython-312/pointnet2_ops/_ext-src/src
#   [1/9] /usr/local/cuda/bin/nvcc --generate-dependencies-with-compile --dependency-output /tmp/Pointnet2_PyTorch/pointnet2_ops_lib/build/temp.linux-x86_64-cpython-312/pointnet2_ops/_ext-src/src/sampling_gpu.o.d -I/tmp/Pointnet2_PyTorch/pointnet2_ops_lib/pointnet2_ops/_ext-src/include -I/usr/local/lib/python3.12/dist-packages/torch/include -I/usr/local/lib/python3.12/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/cuda/include -I/usr/include/python3.12 -c -c /tmp/Pointnet2_PyTorch/pointnet2_ops_lib/pointnet2_ops/_ext-src/src/sampling_gpu.cu -o /tmp/Pointnet2_PyTorch/pointnet2_ops_lib/build/temp.linux-x86_64-cpython-312/pointnet2_ops/_ext-src/src/sampling_gpu.o -D__CUDA_NO_HALF_OPERATORS__ -D__CUDA_NO_HALF_CONVERSIONS__ -D__CUDA_NO_BFLOAT16_CONVERSIONS__ -D__CUDA_NO_HALF2_OPERATORS__ --expt-relaxed-constexpr --compiler-options ''"'"'-fPIC'"'"'' -O3 -Xfatbin -compress-all -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=_ext -gencode=arch=compute_80,code=sm_80 -std=c++17
#   [2/9] /usr/local/cuda/bin/nvcc --generate-dependencies-with-compile --dependency-output /tmp/Pointnet2_PyTorch/pointnet2_ops_lib/build/temp.linux-x86_64-cpython-312/pointnet2_ops/_ext-src/src/interpolate_gpu.o.d -I/tmp/Pointnet2_PyTorch/pointnet2_ops_lib/pointnet2_ops/_ext-src/include -I/usr/local/lib/python3.12/dist-packages/torch/include -I/usr/local/lib/python3.12/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/cuda/include -I/usr/include/python3.12 -c -c /tmp/Pointnet2_PyTorch/pointnet2_ops_lib/pointnet2_ops/_ext-src/src/interpolate_gpu.cu -o /tmp/Pointnet2_PyTorch/pointnet2_ops_lib/build/temp.linux-x86_64-cpython-312/pointnet2_ops/_ext-src/src/interpolate_gpu.o -D__CUDA_NO_HALF_OPERATORS__ -D__CUDA_NO_HALF_CONVERSIONS__ -D__CUDA_NO_BFLOAT16_CONVERSIONS__ -D__CUDA_NO_HALF2_OPERATORS__ --expt-relaxed-constexpr --compiler-options ''"'"'-fPIC'"'"'' -O3 -Xfatbin -compress-all -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=_ext -gencode=arch=compute_80,code=sm_80 -std=c++17
#   [3/9] /usr/local/cuda/bin/nvcc --generate-dependencies-with-compile --dependency-output /tmp/Pointnet2_PyTorch/pointnet2_ops_lib/build/temp.linux-x86_64-cpython-312/pointnet2_ops/_ext-src/src/ball_query_gpu.o.d -I/tmp/Pointnet2_PyTorch/pointnet2_ops_lib/pointnet2_ops/_ext-src/include -I/usr/local/lib/python3.12/dist-packages/torch/include -I/usr/local/lib/python3.12/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/cuda/include -I/usr/include/python3.12 -c -c /tmp/Pointnet2_PyTorch/pointnet2_ops_lib/pointnet2_ops/_ext-src/src/ball_query_gpu.cu -o /tmp/Pointnet2_PyTorch/pointnet2_ops_lib/build/temp.linux-x86_64-cpython-312/pointnet2_ops/_ext-src/src/ball_query_gpu.o -D__CUDA_NO_HALF_OPERATORS__ -D__CUDA_NO_HALF_CONVERSIONS__ -D__CUDA_NO_BFLOAT16_CONVERSIONS__ -D__CUDA_NO_HALF2_OPERATORS__ --expt-relaxed-constexpr --compiler-options ''"'"'-fPIC'"'"'' -O3 -Xfatbin -compress-all -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=_ext -gencode=arch=compute_80,code=sm_80 -std=c++17
#   [4/9] /usr/local/cuda/bin/nvcc --generate-dependencies-with-compile --dependency-output /tmp/Pointnet2_PyTorch/pointnet2_ops_lib/build/temp.linux-x86_64-cpython-312/pointnet2_ops/_ext-src/src/group_points_gpu.o.d -I/tmp/Pointnet2_PyTorch/pointnet2_ops_lib/pointnet2_ops/_ext-src/include -I/usr/local/lib/python3.12/dist-packages/torch/include -I/usr/local/lib/python3.12/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/cuda/include -I/usr/include/python3.12 -c -c /tmp/Pointnet2_PyTorch/pointnet2_ops_lib/pointnet2_ops/_ext-src/src/group_points_gpu.cu -o /tmp/Pointnet2_PyTorch/pointnet2_ops_lib/build/temp.linux-x86_64-cpython-312/pointnet2_ops/_ext-src/src/group_points_gpu.o -D__CUDA_NO_HALF_OPERATORS__ -D__CUDA_NO_HALF_CONVERSIONS__ -D__CUDA_NO_BFLOAT16_CONVERSIONS__ -D__CUDA_NO_HALF2_OPERATORS__ --expt-relaxed-constexpr --compiler-options ''"'"'-fPIC'"'"'' -O3 -Xfatbin -compress-all -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=_ext -gencode=arch=compute_80,code=sm_80 -std=c++17
#   [5/9] c++ -MMD -MF /tmp/Pointnet2_PyTorch/pointnet2_ops_lib/build/temp.linux-x86_64-cpython-312/pointnet2_ops/_ext-src/src/sampling.o.d -fno-strict-overflow -Wsign-compare -DNDEBUG -g -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -I/tmp/Pointnet2_PyTorch/pointnet2_ops_lib/pointnet2_ops/_ext-src/include -I/usr/local/lib/python3.12/dist-packages/torch/include -I/usr/local/lib/python3.12/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/cuda/include -I/usr/include/python3.12 -c -c /tmp/Pointnet2_PyTorch/pointnet2_ops_lib/pointnet2_ops/_ext-src/src/sampling.cpp -o /tmp/Pointnet2_PyTorch/pointnet2_ops_lib/build/temp.linux-x86_64-cpython-312/pointnet2_ops/_ext-src/src/sampling.o -O3 -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=_ext -std=c++17
#   [6/9] c++ -MMD -MF /tmp/Pointnet2_PyTorch/pointnet2_ops_lib/build/temp.linux-x86_64-cpython-312/pointnet2_ops/_ext-src/src/bindings.o.d -fno-strict-overflow -Wsign-compare -DNDEBUG -g -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -I/tmp/Pointnet2_PyTorch/pointnet2_ops_lib/pointnet2_ops/_ext-src/include -I/usr/local/lib/python3.12/dist-packages/torch/include -I/usr/local/lib/python3.12/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/cuda/include -I/usr/include/python3.12 -c -c /tmp/Pointnet2_PyTorch/pointnet2_ops_lib/pointnet2_ops/_ext-src/src/bindings.cpp -o /tmp/Pointnet2_PyTorch/pointnet2_ops_lib/build/temp.linux-x86_64-cpython-312/pointnet2_ops/_ext-src/src/bindings.o -O3 -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=_ext -std=c++17
#   [7/9] c++ -MMD -MF /tmp/Pointnet2_PyTorch/pointnet2_ops_lib/build/temp.linux-x86_64-cpython-312/pointnet2_ops/_ext-src/src/group_points.o.d -fno-strict-overflow -Wsign-compare -DNDEBUG -g -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -I/tmp/Pointnet2_PyTorch/pointnet2_ops_lib/pointnet2_ops/_ext-src/include -I/usr/local/lib/python3.12/dist-packages/torch/include -I/usr/local/lib/python3.12/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/cuda/include -I/usr/include/python3.12 -c -c /tmp/Pointnet2_PyTorch/pointnet2_ops_lib/pointnet2_ops/_ext-src/src/group_points.cpp -o /tmp/Pointnet2_PyTorch/pointnet2_ops_lib/build/temp.linux-x86_64-cpython-312/pointnet2_ops/_ext-src/src/group_points.o -O3 -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=_ext -std=c++17
#   [8/9] c++ -MMD -MF /tmp/Pointnet2_PyTorch/pointnet2_ops_lib/build/temp.linux-x86_64-cpython-312/pointnet2_ops/_ext-src/src/interpolate.o.d -fno-strict-overflow -Wsign-compare -DNDEBUG -g -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -I/tmp/Pointnet2_PyTorch/pointnet2_ops_lib/pointnet2_ops/_ext-src/include -I/usr/local/lib/python3.12/dist-packages/torch/include -I/usr/local/lib/python3.12/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/cuda/include -I/usr/include/python3.12 -c -c /tmp/Pointnet2_PyTorch/pointnet2_ops_lib/pointnet2_ops/_ext-src/src/interpolate.cpp -o /tmp/Pointnet2_PyTorch/pointnet2_ops_lib/build/temp.linux-x86_64-cpython-312/pointnet2_ops/_ext-src/src/interpolate.o -O3 -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=_ext -std=c++17
#   [9/9] c++ -MMD -MF /tmp/Pointnet2_PyTorch/pointnet2_ops_lib/build/temp.linux-x86_64-cpython-312/pointnet2_ops/_ext-src/src/ball_query.o.d -fno-strict-overflow -Wsign-compare -DNDEBUG -g -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -I/tmp/Pointnet2_PyTorch/pointnet2_ops_lib/pointnet2_ops/_ext-src/include -I/usr/local/lib/python3.12/dist-packages/torch/include -I/usr/local/lib/python3.12/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/cuda/include -I/usr/include/python3.12 -c -c /tmp/Pointnet2_PyTorch/pointnet2_ops_lib/pointnet2_ops/_ext-src/src/ball_query.cpp -o /tmp/Pointnet2_PyTorch/pointnet2_ops_lib/build/temp.linux-x86_64-cpython-312/pointnet2_ops/_ext-src/src/ball_query.o -O3 -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=_ext -std=c++17
#   x86_64-linux-gnu-g++ -fno-strict-overflow -Wsign-compare -DNDEBUG -g -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -g -fwrapv -O2 /tmp/Pointnet2_PyTorch/pointnet2_ops_lib/build/temp.linux-x86_64-cpython-312/pointnet2_ops/_ext-src/src/ball_query.o /tmp/Pointnet2_PyTorch/pointnet2_ops_lib/build/temp.linux-x86_64-cpython-312/pointnet2_ops/_ext-src/src/ball_query_gpu.o /tmp/Pointnet2_PyTorch/pointnet2_ops_lib/build/temp.linux-x86_64-cpython-312/pointnet2_ops/_ext-src/src/bindings.o /tmp/Pointnet2_PyTorch/pointnet2_ops_lib/build/temp.linux-x86_64-cpython-312/pointnet2_ops/_ext-src/src/group_points.o /tmp/Pointnet2_PyTorch/pointnet2_ops_lib/build/temp.linux-x86_64-cpython-312/pointnet2_ops/_ext-src/src/group_points_gpu.o /tmp/Pointnet2_PyTorch/pointnet2_ops_lib/build/temp.linux-x86_64-cpython-312/pointnet2_ops/_ext-src/src/interpolate.o /tmp/Pointnet2_PyTorch/pointnet2_ops_lib/build/temp.linux-x86_64-cpython-312/pointnet2_ops/_ext-src/src/interpolate_gpu.o /tmp/Pointnet2_PyTorch/pointnet2_ops_lib/build/temp.linux-x86_64-cpython-312/pointnet2_ops/_ext-src/src/sampling.o /tmp/Pointnet2_PyTorch/pointnet2_ops_lib/build/temp.linux-x86_64-cpython-312/pointnet2_ops/_ext-src/src/sampling_gpu.o -L/usr/local/lib/python3.12/dist-packages/torch/lib -L/usr/local/cuda/lib64 -L/usr/lib/x86_64-linux-gnu -lc10 -ltorch -ltorch_cpu -ltorch_python -lcudart -lc10_cuda -ltorch_cuda -o build/lib.linux-x86_64-cpython-312/pointnet2_ops/_ext.cpython-312-x86_64-linux-gnu.so
#   /usr/local/lib/python3.12/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
#   !!
#
#           ********************************************************************************
#           Please avoid running ``setup.py`` directly.
#           Instead, use pypa/build, pypa/installer or other
#           standards-based tools.
#
#           See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#           ********************************************************************************
#
#   !!
#     self.initialize_options()
#   installing to build/bdist.linux-x86_64/wheel
#   running install
#   running install_lib
#   creating build/bdist.linux-x86_64/wheel
#   creating build/bdist.linux-x86_64/wheel/pointnet2_ops
#   copying build/lib.linux-x86_64-cpython-312/pointnet2_ops/pointnet2_utils.py -> build/bdist.linux-x86_64/wheel/./pointnet2_ops
#   copying build/lib.linux-x86_64-cpython-312/pointnet2_ops/pointnet2_modules.py -> build/bdist.linux-x86_64/wheel/./pointnet2_ops
#   copying build/lib.linux-x86_64-cpython-312/pointnet2_ops/_ext.cpython-312-x86_64-linux-gnu.so -> build/bdist.linux-x86_64/wheel/./pointnet2_ops
#   copying build/lib.linux-x86_64-cpython-312/pointnet2_ops/__init__.py -> build/bdist.linux-x86_64/wheel/./pointnet2_ops
#   copying build/lib.linux-x86_64-cpython-312/pointnet2_ops/_version.py -> build/bdist.linux-x86_64/wheel/./pointnet2_ops
#   creating build/bdist.linux-x86_64/wheel/pointnet2_ops/_ext-src
#   creating build/bdist.linux-x86_64/wheel/pointnet2_ops/_ext-src/include
#   copying build/lib.linux-x86_64-cpython-312/pointnet2_ops/_ext-src/include/utils.h -> build/bdist.linux-x86_64/wheel/./pointnet2_ops/_ext-src/include
#   copying build/lib.linux-x86_64-cpython-312/pointnet2_ops/_ext-src/include/interpolate.h -> build/bdist.linux-x86_64/wheel/./pointnet2_ops/_ext-src/include
#   copying build/lib.linux-x86_64-cpython-312/pointnet2_ops/_ext-src/include/ball_query.h -> build/bdist.linux-x86_64/wheel/./pointnet2_ops/_ext-src/include
#   copying build/lib.linux-x86_64-cpython-312/pointnet2_ops/_ext-src/include/cuda_utils.h -> build/bdist.linux-x86_64/wheel/./pointnet2_ops/_ext-src/include
#   copying build/lib.linux-x86_64-cpython-312/pointnet2_ops/_ext-src/include/group_points.h -> build/bdist.linux-x86_64/wheel/./pointnet2_ops/_ext-src/include
#   copying build/lib.linux-x86_64-cpython-312/pointnet2_ops/_ext-src/include/sampling.h -> build/bdist.linux-x86_64/wheel/./pointnet2_ops/_ext-src/include
#   creating build/bdist.linux-x86_64/wheel/pointnet2_ops/_ext-src/src
#   copying build/lib.linux-x86_64-cpython-312/pointnet2_ops/_ext-src/src/interpolate_gpu.cu -> build/bdist.linux-x86_64/wheel/./pointnet2_ops/_ext-src/src
#   copying build/lib.linux-x86_64-cpython-312/pointnet2_ops/_ext-src/src/sampling_gpu.cu -> build/bdist.linux-x86_64/wheel/./pointnet2_ops/_ext-src/src
#   copying build/lib.linux-x86_64-cpython-312/pointnet2_ops/_ext-src/src/sampling.cpp -> build/bdist.linux-x86_64/wheel/./pointnet2_ops/_ext-src/src
#   copying build/lib.linux-x86_64-cpython-312/pointnet2_ops/_ext-src/src/ball_query.cpp -> build/bdist.linux-x86_64/wheel/./pointnet2_ops/_ext-src/src
#   copying build/lib.linux-x86_64-cpython-312/pointnet2_ops/_ext-src/src/group_points_gpu.cu -> build/bdist.linux-x86_64/wheel/./pointnet2_ops/_ext-src/src
#   copying build/lib.linux-x86_64-cpython-312/pointnet2_ops/_ext-src/src/ball_query_gpu.cu -> build/bdist.linux-x86_64/wheel/./pointnet2_ops/_ext-src/src
#   copying build/lib.linux-x86_64-cpython-312/pointnet2_ops/_ext-src/src/group_points.cpp -> build/bdist.linux-x86_64/wheel/./pointnet2_ops/_ext-src/src
#   copying build/lib.linux-x86_64-cpython-312/pointnet2_ops/_ext-src/src/interpolate.cpp -> build/bdist.linux-x86_64/wheel/./pointnet2_ops/_ext-src/src
#   copying build/lib.linux-x86_64-cpython-312/pointnet2_ops/_ext-src/src/bindings.cpp -> build/bdist.linux-x86_64/wheel/./pointnet2_ops/_ext-src/src
#   running install_egg_info
#   Copying pointnet2_ops.egg-info to build/bdist.linux-x86_64/wheel/./pointnet2_ops-3.0.0-py3.12.egg-info
#   running install_scripts
#   creating build/bdist.linux-x86_64/wheel/pointnet2_ops-3.0.0.dist-info/WHEEL
#   creating '/tmp/pip-wheel-3ze2vlgy/pointnet2_ops-3.0.0-cp312-cp312-linux_x86_64.whl' and adding 'build/bdist.linux-x86_64/wheel' to it
#   adding 'pointnet2_ops/__init__.py'
#   adding 'pointnet2_ops/_ext.cpython-312-x86_64-linux-gnu.so'
#   adding 'pointnet2_ops/_version.py'
#   adding 'pointnet2_ops/pointnet2_modules.py'
#   adding 'pointnet2_ops/pointnet2_utils.py'
#   adding 'pointnet2_ops/_ext-src/include/ball_query.h'
#   adding 'pointnet2_ops/_ext-src/include/cuda_utils.h'
#   adding 'pointnet2_ops/_ext-src/include/group_points.h'
#   adding 'pointnet2_ops/_ext-src/include/interpolate.h'
#   adding 'pointnet2_ops/_ext-src/include/sampling.h'
#   adding 'pointnet2_ops/_ext-src/include/utils.h'
#   adding 'pointnet2_ops/_ext-src/src/ball_query.cpp'
#   adding 'pointnet2_ops/_ext-src/src/ball_query_gpu.cu'
#   adding 'pointnet2_ops/_ext-src/src/bindings.cpp'
#   adding 'pointnet2_ops/_ext-src/src/group_points.cpp'
#   adding 'pointnet2_ops/_ext-src/src/group_points_gpu.cu'
#   adding 'pointnet2_ops/_ext-src/src/interpolate.cpp'
#   adding 'pointnet2_ops/_ext-src/src/interpolate_gpu.cu'
#   adding 'pointnet2_ops/_ext-src/src/sampling.cpp'
#   adding 'pointnet2_ops/_ext-src/src/sampling_gpu.cu'
#   adding 'pointnet2_ops-3.0.0.dist-info/METADATA'
#   adding 'pointnet2_ops-3.0.0.dist-info/WHEEL'
#   adding 'pointnet2_ops-3.0.0.dist-info/top_level.txt'
#   adding 'pointnet2_ops-3.0.0.dist-info/RECORD'
#   removing build/bdist.linux-x86_64/wheel
#   Building wheel for pointnet2_ops (setup.py) ... done
#   Created wheel for pointnet2_ops: filename=pointnet2_ops-3.0.0-cp312-cp312-linux_x86_64.whl size=10101011 sha256=a8a2562065afd354af2589a2755b6efcb2d8b3f8dff06d740e668c23a0407959
#   Stored in directory: /tmp/pip-ephem-wheel-cache-_mak41fo/wheels/1f/b1/c1/af9ecab9232d49f0fd27f1c73d061e81c7acd0d9f8632fec56
# Successfully built pointnet2_ops
# Installing collected packages: pointnet2_ops
# Successfully installed pointnet2_ops-3.0.0
# /content
# pointnet2_ops: インストール成功

# %%
# KNN_CUDA (kNN 近傍探索)
try:
    from knn_cuda import KNN
    print('knn_cuda: すでにインストール済み')
except ImportError:
    print('KNN_CUDA をインストール中...')
    # !pip install --upgrade https://github.com/unlimblue/KNN_CUDA/releases/download/0.2/KNN_CUDA-0.2-py3-none-any.whl -q
    from knn_cuda import KNN
    print('knn_cuda: インストール完了')
# Out:
# KNN_CUDA をインストール中...
# knn_cuda: インストール完了

# %%
# ビルド確認
from pointnet2_ops import pointnet2_utils
from knn_cuda import KNN
print('pointnet2_ops + KNN_CUDA: OK')
# Out:
# pointnet2_ops + KNN_CUDA: OK

# %% [markdown]
# ## Step 4 — PatchAlign3D & Phase3 パスをロード

# %%
import sys, os, types

# PatchAlign3D 参照リポジトリ
PA3D_SRC = f'{PA3D_REF}/src'
if PA3D_SRC not in sys.path:
    sys.path.insert(0, PA3D_SRC)

# patchalign3d パッケージとして登録
if 'patchalign3d' not in sys.modules:
    mod = types.ModuleType('patchalign3d')
    mod.__path__ = [PA3D_SRC]
    sys.modules['patchalign3d'] = mod

# Phase3_Training_v2 ディレクトリ (phase3_models / phase3_datasets / phase3_losses をインポートするため)
if PHASE3_DIR not in sys.path:
    sys.path.insert(0, PHASE3_DIR)

# 確認
import phase3_models, phase3_datasets
print('PatchAlign3D + Phase3_Training_v2: パス設定 OK')
# Out:
# PatchAlign3D + Phase3_Training_v2: パス設定 OK

# %% [markdown]
# ## Step 5 — データセット検証
#
# PLY ファイルと `candidates.json` の整合性を確認する。
# 期待: 20 PLY × 32 パッチ × 5 テキスト

# %%
import json
from pathlib import Path

# PLY ファイル一覧
ply_files = sorted(Path(PLY_DIR).glob('*.ply'))
print(f'PLY ファイル数: {len(ply_files)}')
for p in ply_files:
    print(f'  {p.name}')

print()

# candidates.json
with open(JSON_PATH, 'r', encoding='utf-8') as f:
    candidates = json.load(f)

print(f'candidates.json キー数 (患者数): {len(candidates)}')
for pat_id, patches in list(candidates.items())[:3]:
    print(f'  {pat_id}: {len(patches)} パッチ, texts[0] = "{patches[0]["texts"][0][:50]}..."')
print('  ...')

# 整合性チェック: PLY ↔ JSON キーの対応
ply_stems = {p.stem for p in ply_files}
json_keys = set(candidates.keys())
matched = ply_stems & json_keys
print(f'\n整合: PLY={len(ply_stems)}, JSON={len(json_keys)}, マッチ={len(matched)}')
if ply_stems - json_keys:
    print(f'  JSON にない PLY: {ply_stems - json_keys}')
if json_keys - ply_stems:
    print(f'  PLY にない JSON キー: {json_keys - ply_stems}')
assert len(matched) > 0, 'PLY と JSON のマッチが 0 件です！パスを確認してください。'
print('データセット整合性 OK')
# Out:
# PLY ファイル数: 20
#   Pat 10na_norm.ply
#   Pat 10nb_norm.ply
#   Pat 1a_norm.ply
#   Pat 1b_norm.ply
#   Pat 2a_norm.ply
#   Pat 2b_norm.ply
#   Pat 3a_norm.ply
#   Pat 3b_norm.ply
#   Pat 4a_norm.ply
#   Pat 4b_norm.ply
#   Pat 5a_norm.ply
#   Pat 5b_norm.ply
#   Pat 6a_norm.ply
#   Pat 6b_norm.ply
#   Pat 7a_norm.ply
#   Pat 7b_norm.ply
#   Pat 8a_norm.ply
#   Pat 8b_norm.ply
#   Pat 9na_norm.ply
#   Pat 9nb_norm.ply
#
# candidates.json キー数 (患者数): 20
#   Pat 10na_norm: 32 パッチ, texts[0] = "Right body of mandible along the rounded inferior ..."
#   Pat 10nb_norm: 32 パッチ, texts[0] = "Left coronoid process, a pointed triangular projec..."
#   Pat 1a_norm: 32 パッチ, texts[0] = "Midline mental protuberance forms a broad convex p..."
#   ...
#
# 整合: PLY=20, JSON=20, マッチ=20
# データセット整合性 OK

# %%
# DentalPatchDataset で実際にロードできるか確認
from phase3_datasets.dental_dataset import DentalPatchDataset

ds_check = DentalPatchDataset(
    ply_dir    = PLY_DIR,
    json_path  = JSON_PATH,
    npoints    = 2048,
    mode       = '3b',
    split      = 'train',
    val_ratio  = 0.2,
    seed       = 42,
)
print(f'Train 患者数: {len(ds_check)}')

sample = ds_check[0]
print(f'points       : {sample["points"].shape}  (期待: torch.Size([3, 2048]))')
print(f'point_labels : {sample["point_labels"].shape}')
print(f'label_masks  : {sample["label_masks"].shape}')
print(f'label_names  : {len(sample["label_names"])} テキスト (先頭: "{sample["label_names"][0][:50]}...")')
print(f'item_id      : {sample["item_id"]}')
print('\nデータセットロード OK')
# Out:
# Train 患者数: 16
# points       : torch.Size([3, 2048])  (期待: torch.Size([3, 2048]))
# point_labels : torch.Size([2048])
# label_masks  : torch.Size([32, 2048])
# label_names  : 32 テキスト (先頭: "Right basal border of the mandibular body with a g...")
# item_id      : Pat 10na_norm
#
# データセットロード OK

# %% [markdown]
# ## Step 6 — BiomedCLIP ロード確認
#
# > `open_clip` の `hf-hub:` 形式で HuggingFace からロードします。
# > テキスト出力次元は **512** (ViT-bigG-14 の 1280 から変更)。
# > 初回は数百 MB のダウンロードが発生します (ViT-bigG-14 の 10GB より大幅に軽量)。

# %%
import open_clip, torch, torch.nn.functional as F
from google.colab import userdata
from huggingface_hub import login

login(token=userdata.get('HF_TOKEN'))

BIOMEDCLIP_HUB = 'hf-hub:microsoft/BiomedCLIP-PubMedBERT_256-vit_base_patch16_224'
print(f'BiomedCLIP をロード中: {BIOMEDCLIP_HUB}')
clip_model, _, _ = open_clip.create_model_and_transforms(BIOMEDCLIP_HUB)
clip_model = clip_model.to(device)
clip_model.eval()
tokenizer = open_clip.get_tokenizer(BIOMEDCLIP_HUB)

def encode_texts(texts: list[str]) -> torch.Tensor:
    """テキストリストを正規化済み BiomedCLIP 特徴 (T, 512) に変換"""
    with torch.no_grad():
        toks = tokenizer(texts).to(device)
        return F.normalize(clip_model.encode_text(toks), dim=-1)

# 動作確認
with torch.no_grad():
    feat = clip_model.encode_text(tokenizer(['mandibular condyle']).to(device))
print(f'テキスト特徴次元: {feat.shape[-1]}  (期待値: 512)')
assert feat.shape[-1] == 512, f'次元不一致: {feat.shape[-1]}'

# 学習はサブプロセスで行うためメモリ節約 (text_cache が GPU 管理する)
clip_model = clip_model.cpu()
print('BiomedCLIP ロード OK')
# Out:
# BiomedCLIP をロード中: hf-hub:microsoft/BiomedCLIP-PubMedBERT_256-vit_base_patch16_224
# open_clip_config.json:   0%|          | 0.00/707 [00:00<?, ?B/s]
# open_clip_pytorch_model.bin:   0%|          | 0.00/784M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/385 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# テキスト特徴次元: 512  (期待値: 512)
# BiomedCLIP ロード OK

# %% [markdown]
# ## Step 7 — HuggingFace チェックポイントのダウンロード
#
# > Stage 2 事前学習済みチェックポイント `patchalign3d.pt` をダウンロードします。
# > **注意**: 公開チェックポイントは `color=False` (入力 C=3, xyz のみ) で学習済み。

# %%
import os
from huggingface_hub import hf_hub_download
import torch

FILENAME  = 'patchalign3d.pt'
CKPT_PATH = os.path.join(CKPT_DIR, FILENAME)

if os.path.exists(CKPT_PATH):
    print(f'チェックポイント既存: {CKPT_PATH}')
else:
    print(f'チェックポイントをダウンロード中... ({FILENAME})')
    downloaded = hf_hub_download(
        repo_id  = 'patchalign3d/patchalign3d-encoder',
        filename = FILENAME,
    )
    import shutil
    shutil.copy(downloaded, CKPT_PATH)
    print(f'保存: {CKPT_PATH}')

# チェックポイントの形式確認
ckpt = torch.load(CKPT_PATH, map_location='cpu', weights_only=False)
keys = list(ckpt.keys()) if isinstance(ckpt, dict) else ['(tensor)']
print(f'チェックポイントキー: {keys[:8]}')
print('チェックポイント確認 OK')
# Out:
# チェックポイント既存: /content/drive/MyDrive/2026研究/ULIP_PointLLM/checkpoints/patchalign3d/patchalign3d.pt
# チェックポイントキー: ['model', 'proj']
# チェックポイント確認 OK

# %% [markdown]
# ## Step 8 — Colab 用 YAML 設定ファイルの生成
#
# ローカルの相対パスを Colab 絶対パスで上書きした設定ファイルを `/content/` 以下に書き出します。

# %%
import yaml, os

# ===== Stage 3a 設定 (BiomedCLIP, clip_dim=512) =====
cfg_3a = {
    'seed': 42,
    'output_dir': OUT_3A,
    'data': {
        'ply_dir':   PLY_DIR,
        'json_path': JSON_PATH,
        'npoints':   2048,
        'val_ratio': 0.2,
    },
    'clip': {
        'model':          'hf-hub:microsoft/BiomedCLIP-PubMedBERT_256-vit_base_patch16_224',
        'pretrained':     '',
        'cache_capacity': 5000,
    },
    'model': {
        'trans_dim':       384,
        'depth':           12,
        'drop_path_rate':  0.1,
        'cls_dim':         50,
        'num_heads':       6,
        'group_size':      32,
        'num_group':       128,
        'encoder_dims':    256,
        'color':           False,
        'num_classes':     16,
        'clip_dim':        512,    # BiomedCLIP テキスト出力次元
        'clip_tau':        0.07,
        'stage2_ckpt':     CKPT_PATH,
    },
    'loss': {
        'lambda_infonce': 1.0,
        'lambda_kd':      0.0,
    },
    'training': {
        'epochs':       1000,
        'batch_size':   4,
        'lr':           1e-5,
        'lr_min':       1e-7,
        'weight_decay': 0.2,
        'num_workers':  2,
        'eval_every':   20,
        'save_every':   100,
    },
}

CFG_3A_PATH = '/content/stage3a_colab.yaml'
with open(CFG_3A_PATH, 'w', encoding='utf-8') as f:
    yaml.dump(cfg_3a, f, allow_unicode=True, sort_keys=False)
print(f'Stage 3a config: {CFG_3A_PATH}')

# ===== Stage 3b 設定 (BiomedCLIP, clip_dim=512) =====
STAGE3A_LAST = os.path.join(OUT_3A, 'stage3a_last.pt')

cfg_3b = {
    'seed': 42,
    'output_dir': OUT_3B,
    'data': {
        'ply_dir':      PLY_DIR,
        'json_path':    JSON_PATH,
        'npoints':      2048,
        'val_ratio':    0.2,
        'text_augment': True,
    },
    'clip': {
        'model':          'hf-hub:microsoft/BiomedCLIP-PubMedBERT_256-vit_base_patch16_224',
        'pretrained':     '',
        'cache_capacity': 10000,
    },
    'model': {
        'trans_dim':       384,
        'depth':           12,
        'drop_path_rate':  0.1,
        'cls_dim':         50,
        'num_heads':       6,
        'group_size':      32,
        'num_group':       128,
        'encoder_dims':    256,
        'color':           False,
        'num_classes':     16,
        'clip_dim':        512,    # BiomedCLIP テキスト出力次元
        'clip_tau':        0.07,
        'stage2_ckpt':     CKPT_PATH,
    },
    'loss': {
        'lambda_bce':           1.0,
        'lambda_kd':            0.0,
        'lambda_ewc':           1.0,
        'lambda_kd_text':       0.0,
        'ewc_fisher_batches':   50,
    },
    'training': {
        'epochs':        1000,
        'batch_size':    1024,
        'lr':            1e-4,
        'weight_decay':  0.05,
        'warmup_epochs': 5,
        'num_workers':   2,
        'eval_every':    5,
        'save_every':    50,
    },
}

CFG_3B_PATH = '/content/stage3b_colab.yaml'
with open(CFG_3B_PATH, 'w', encoding='utf-8') as f:
    yaml.dump(cfg_3b, f, allow_unicode=True, sort_keys=False)
print(f'Stage 3b config: {CFG_3B_PATH}')
print('\nColab 用 YAML 設定ファイル生成 OK')
# Out:
# Stage 3a config: /content/stage3a_colab.yaml
# Stage 3b config: /content/stage3b_colab.yaml
#
# Colab 用 YAML 設定ファイル生成 OK

# %% [markdown]
# ## Step 9 — Stage 3a 学習 (領域パッチ InfoNCE、30 エポック)
#
# ```
# 点群 (2048点)
#  ↓ forward_patches
# patch_emb (B, 384, 128)  +  patch_idx (B, 128, 32)
#  ↓ proj
# patch_feat (B, 128, 1280)
#  ↓ InfoNCE vs 9-octant テキスト
# Loss = InfoNCE + λ_kd × MSE(student, teacher)
# ```
#
# > **出力**: `outputs/stage3a/checkpoints/best.pt` + `stage3a_last.pt`

# %%
# %cd {PHASE3_DIR}
# !python train_stage3a.py --config {CFG_3A_PATH}
# Out:
# /content/drive/MyDrive/2026研究/ULIP_PointLLM/DentalPatchAligned3D/Phase3_Training_v2
# /usr/local/lib/python3.12/dist-packages/timm/models/layers/__init__.py:49: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# 2026-04-21 12:01:02,437 INFO Config: {'seed': 42, 'output_dir': '/content/drive/MyDrive/2026研究/ULIP_PointLLM/DentalPatchAligned3D/Phase3_Training_v2/outputs/stage3a', 'data': {'ply_dir': '/content/drive/MyDrive/2026研究/Dataset/6167726/STLs/STLs/normPLYs', 'json_path': '/content/drive/MyDrive/2026研究/ULIP_PointLLM/data/DentalPatchData/dental_vocab/candidates.json', 'npoints': 2048, 'val_ratio': 0.2}, 'clip': {'model': 'hf-hub:microsoft/BiomedCLIP-PubMedBERT_256-vit_base_patch16_224', 'pretrained': '', 'cache_capacity': 5000}, 'model': {'trans_dim': 384, 'depth': 12, 'drop_path_rate': 0.1, 'cls_dim': 50, 'num_heads': 6, 'group_size': 32, 'num_group': 128, 'encoder_dims': 256, 'color': False, 'num_classes': 16, 'clip_dim': 512, 'clip_tau': 0.07, 'stage2_ckpt': '/content/drive/MyDrive/2026研究/ULIP_PointLLM/checkpoints/patchalign3d/patchalign3d.pt'}, 'loss': {'lambda_infonce': 1.0, 'lambda_kd': 0.0}, 'training': {'epochs': 1000, 'batch_size': 4, 'lr': 1e-05, 'lr_min': 1e-07, 'weight_decay': 0.2, 'num_workers': 2, 'eval_every': 20, 'save_every': 100}}
# 2026-04-21 12:01:02,438 INFO Device: cuda
# 2026-04-21 12:01:02,456 INFO Train: 16 患者  Val: 4 患者
# 2026-04-21 12:01:05,628 INFO NumExpr defaulting to 12 threads.
# 2026-04-21 12:01:06,342 INFO Parsing model identifier. Schema: hf-hub, Identifier: microsoft/BiomedCLIP-PubMedBERT_256-vit_base_patch16_224
# 2026-04-21 12:01:06,343 INFO Attempting to load config from HF Hub: microsoft/BiomedCLIP-PubMedBERT_256-vit_base_patch16_224
# 2026-04-21 12:01:06,482 INFO HTTP Request: HEAD https://huggingface.co/microsoft/BiomedCLIP-PubMedBERT_256-vit_base_patch16_224/resolve/main/open_clip_config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-04-21 12:01:06,498 INFO HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/microsoft/BiomedCLIP-PubMedBERT_256-vit_base_patch16_224/9f341de24bfb00180f1b847274256e9b65a3a32e/open_clip_config.json "HTTP/1.1 200 OK"
# 2026-04-21 12:01:06,499 INFO Loaded model config from HF Hub: microsoft/BiomedCLIP-PubMedBERT_256-vit_base_patch16_224
# 2026-04-21 12:01:06,557 INFO HTTP Request: HEAD https://huggingface.co/microsoft/BiomedCLIP-PubMedBERT_256-vit_base_patch16_224/resolve/main/open_clip_model.safetensors "HTTP/1.1 404 Not Found"
# 2026-04-21 12:01:06,615 INFO HTTP Request: HEAD https://huggingface.co/microsoft/BiomedCLIP-PubMedBERT_256-vit_base_patch16_224/resolve/main/open_clip_pytorch_model.bin "HTTP/1.1 302 Found"
# 2026-04-21 12:01:06,617 INFO Found default weights file on HF Hub: /root/.cache/huggingface/hub/models--microsoft--BiomedCLIP-PubMedBERT_256-vit_base_patch16_224/snapshots/9f341de24bfb00180f1b847274256e9b65a3a32e/open_clip_pytorch_model.bin
# 2026-04-21 12:01:06,617 INFO Instantiating model architecture: CustomTextCLIP
# 2026-04-21 12:01:07,769 INFO HTTP Request: HEAD https://huggingface.co/microsoft/BiomedNLP-BiomedBERT-base-uncased-abstract/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-04-21 12:01:07,784 INFO HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/microsoft/BiomedNLP-BiomedBERT-base-uncased-abstract/d673b8835373c6fa116d6d8006b33d48734e305d/config.json "HTTP/1.1 200 OK"
# 2026-04-21 12:01:09,278 INFO Loading full pretrained weights from: /root/.cache/huggingface/hub/models--microsoft--BiomedCLIP-PubMedBERT_256-vit_base_patch16_224/snapshots/9f341de24bfb00180f1b847274256e9b65a3a32e/open_clip_pytorch_model.bin
# 2026-04-21 12:01:09,843 INFO Final image preprocessing configuration set: {'size': (224, 224), 'mode': 'RGB', 'mean': [0.48145466, 0.4578275, 0.40821073], 'std': [0.26862954, 0.26130258, 0.27577711], 'interpolation': 'bicubic', 'resize_mode': 'shortest', 'fill_color': 0}
# 2026-04-21 12:01:09,843 INFO Model hf-hub:microsoft/BiomedCLIP-PubMedBERT_256-vit_base_patch16_224 creation process complete.
# 2026-04-21 12:01:10,358 INFO Parsing tokenizer identifier. Schema: hf-hub, Identifier: microsoft/BiomedCLIP-PubMedBERT_256-vit_base_patch16_224
# 2026-04-21 12:01:10,358 INFO Attempting to load config from hf-hub:microsoft/BiomedCLIP-PubMedBERT_256-vit_base_patch16_224
# 2026-04-21 12:01:10,405 INFO HTTP Request: HEAD https://huggingface.co/microsoft/BiomedCLIP-PubMedBERT_256-vit_base_patch16_224/resolve/main/open_clip_config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-04-21 12:01:10,421 INFO HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/microsoft/BiomedCLIP-PubMedBERT_256-vit_base_patch16_224/9f341de24bfb00180f1b847274256e9b65a3a32e/open_clip_config.json "HTTP/1.1 200 OK"
# 2026-04-21 12:01:10,422 INFO Using HFTokenizer with source: 'microsoft/BiomedNLP-BiomedBERT-base-uncased-abstract', mode: 'None'
# 2026-04-21 12:01:10,484 INFO HTTP Request: HEAD https://huggingface.co/microsoft/BiomedNLP-BiomedBERT-base-uncased-abstract/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-04-21 12:01:10,501 INFO HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/microsoft/BiomedNLP-BiomedBERT-base-uncased-abstract/d673b8835373c6fa116d6d8006b33d48734e305d/config.json "HTTP/1.1 200 OK"
# 2026-04-21 12:01:10,548 INFO HTTP Request: HEAD https://huggingface.co/microsoft/BiomedNLP-BiomedBERT-base-uncased-abstract/resolve/main/tokenizer_config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-04-21 12:01:10,563 INFO HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/microsoft/BiomedNLP-BiomedBERT-base-uncased-abstract/d673b8835373c6fa116d6d8006b33d48734e305d/tokenizer_config.json "HTTP/1.1 200 OK"
# 2026-04-21 12:01:10,616 INFO HTTP Request: GET https://huggingface.co/api/models/microsoft/BiomedNLP-BiomedBERT-base-uncased-abstract/tree/main/additional_chat_templates?recursive=false&expand=false "HTTP/1.1 404 Not Found"
# 2026-04-21 12:01:10,669 INFO HTTP Request: GET https://huggingface.co/api/models/microsoft/BiomedNLP-BiomedBERT-base-uncased-abstract/tree/main?recursive=true&expand=false "HTTP/1.1 200 OK"
# [TextCache] CLIP hf-hub:microsoft/BiomedCLIP-PubMedBERT_256-vit_base_patch16_224 をロード  テキスト次元: 512
# [Stage3] proj: 形状不一致のためスキップ → {'proj.weight', 'proj.bias'}
# [Stage3] proj をランダム初期化 (out=512)
# [Stage3] チェックポイントをロード: /content/drive/MyDrive/2026研究/ULIP_PointLLM/checkpoints/patchalign3d/patchalign3d.pt
# [Stage3] Student: 学習可能 1,873,536 / 総 21,858,816 パラメータ  Proj: 197,120
# 2026-04-21 12:01:12,857 INFO Epoch   1/1000  loss=2.1673  infonce=8.6692  kd=0.0006  temp=14.28  lr=1.00e-05
# 2026-04-21 12:01:13,371 INFO Epoch   2/1000  loss=2.1321  infonce=8.5286  kd=0.0007  temp=14.28  lr=1.00e-05
# 2026-04-21 12:01:13,900 INFO Epoch   3/1000  loss=2.0942  infonce=8.3767  kd=0.0005  temp=14.28  lr=1.00e-05
# 2026-04-21 12:01:14,421 INFO Epoch   4/1000  loss=2.0542  infonce=8.2168  kd=0.0006  temp=14.28  lr=1.00e-05
# 2026-04-21 12:01:14,949 INFO Epoch   5/1000  loss=2.0375  infonce=8.1499  kd=0.0008  temp=14.28  lr=1.00e-05
# 2026-04-21 12:01:15,480 INFO Epoch   6/1000  loss=1.9956  infonce=7.9825  kd=0.0005  temp=14.28  lr=1.00e-05
# 2026-04-21 12:01:16,014 INFO Epoch   7/1000  loss=1.9687  infonce=7.8749  kd=0.0007  temp=14.28  lr=1.00e-05
# 2026-04-21 12:01:16,527 INFO Epoch   8/1000  loss=1.9487  infonce=7.7947  kd=0.0008  temp=14.28  lr=1.00e-05
# 2026-04-21 12:01:17,041 INFO Epoch   9/1000  loss=1.9290  infonce=7.7159  kd=0.0008  temp=14.28  lr=1.00e-05
# 2026-04-21 12:01:17,555 INFO Epoch  10/1000  loss=1.8890  infonce=7.5559  kd=0.0007  temp=14.29  lr=1.00e-05
# 2026-04-21 12:01:18,066 INFO Epoch  11/1000  loss=1.8921  infonce=7.5682  kd=0.0008  temp=14.29  lr=1.00e-05
# 2026-04-21 12:01:18,576 INFO Epoch  12/1000  loss=1.8396  infonce=7.3586  kd=0.0007  temp=14.29  lr=1.00e-05
# 2026-04-21 12:01:19,093 INFO Epoch  13/1000  loss=1.8296  infonce=7.3182  kd=0.0007  temp=14.29  lr=1.00e-05
# 2026-04-21 12:01:19,607 INFO Epoch  14/1000  loss=1.7778  infonce=7.1113  kd=0.0007  temp=14.29  lr=1.00e-05
# 2026-04-21 12:01:20,129 INFO Epoch  15/1000  loss=1.8105  infonce=7.2418  kd=0.0008  temp=14.29  lr=9.99e-06
# 2026-04-21 12:01:20,648 INFO Epoch  16/1000  loss=1.7493  infonce=6.9974  kd=0.0007  temp=14.29  lr=9.99e-06
# 2026-04-21 12:01:21,159 INFO Epoch  17/1000  loss=1.7473  infonce=6.9894  kd=0.0009  temp=14.29  lr=9.99e-06
# 2026-04-21 12:11:35,593 INFO Epoch 983/1000  loss=0.4719  infonce=1.8877  kd=0.0024  temp=14.44  lr=1.07e-07
# 2026-04-21 12:11:36,084 INFO Epoch 984/1000  loss=0.4143  infonce=1.6574  kd=0.0025  temp=14.44  lr=1.06e-07
# 2026-04-21 12:11:36,612 INFO Epoch 985/1000  loss=0.3929  infonce=1.5714  kd=0.0026  temp=14.44  lr=1.05e-07
# 2026-04-21 12:11:37,106 INFO Epoch 986/1000  loss=0.4038  infonce=1.6154  kd=0.0025  temp=14.44  lr=1.05e-07
# 2026-04-21 12:11:37,619 INFO Epoch 987/1000  loss=0.4230  infonce=1.6919  kd=0.0025  temp=14.44  lr=1.04e-07
# 2026-04-21 12:11:38,135 INFO Epoch 988/1000  loss=0.4859  infonce=1.9435  kd=0.0024  temp=14.44  lr=1.04e-07
# 2026-04-21 12:11:38,644 INFO Epoch 989/1000  loss=0.4240  infonce=1.6960  kd=0.0024  temp=14.44  lr=1.03e-07
# 2026-04-21 12:11:39,171 INFO Epoch 990/1000  loss=0.4490  infonce=1.7962  kd=0.0025  temp=14.44  lr=1.02e-07
# 2026-04-21 12:11:39,686 INFO Epoch 991/1000  loss=0.4221  infonce=1.6886  kd=0.0025  temp=14.44  lr=1.02e-07
# 2026-04-21 12:11:40,205 INFO Epoch 992/1000  loss=0.4284  infonce=1.7135  kd=0.0025  temp=14.44  lr=1.02e-07
# 2026-04-21 12:11:40,722 INFO Epoch 993/1000  loss=0.4325  infonce=1.7299  kd=0.0025  temp=14.44  lr=1.01e-07
# 2026-04-21 12:11:41,244 INFO Epoch 994/1000  loss=0.4031  infonce=1.6124  kd=0.0025  temp=14.44  lr=1.01e-07
# 2026-04-21 12:11:41,760 INFO Epoch 995/1000  loss=0.4639  infonce=1.8554  kd=0.0025  temp=14.44  lr=1.01e-07
# 2026-04-21 12:11:42,274 INFO Epoch 996/1000  loss=0.4155  infonce=1.6619  kd=0.0025  temp=14.44  lr=1.00e-07
# 2026-04-21 12:11:42,807 INFO Epoch 997/1000  loss=0.4139  infonce=1.6556  kd=0.0025  temp=14.44  lr=1.00e-07
# 2026-04-21 12:11:44,437 INFO Epoch 998/1000  loss=0.4180  infonce=1.6719  kd=0.0025  temp=14.44  lr=1.00e-07
# 2026-04-21 12:11:44,973 INFO Epoch 999/1000  loss=0.4002  infonce=1.6008  kd=0.0025  temp=14.44  lr=1.00e-07
# 2026-04-21 12:11:45,507 INFO Epoch 1000/1000  loss=0.4406  infonce=1.7622  kd=0.0025  temp=14.44  lr=1.00e-07
# 2026-04-21 12:11:45,640 INFO   -> val_loss=0.6745
# 2026-04-21 12:11:46,373 INFO Stage 3a 完了。最終チェックポイント: /content/drive/MyDrive/2026研究/ULIP_PointLLM/DentalPatchAligned3D/Phase3_Training_v2/outputs/stage3a/stage3a_last.pt
# 2026-04-21 12:11:46,373 INFO 次: train_stage3b.py --init_ckpt <このパス> を実行してください。

# %%
# Stage 3a チェックポイント確認
import os, torch

stage3a_last = os.path.join(OUT_3A, 'stage3a_last.pt')
stage3a_best = os.path.join(OUT_3A, 'checkpoints', 'best.pt')

assert os.path.exists(stage3a_last), f'stage3a_last.pt が見つかりません: {stage3a_last}'
assert os.path.exists(stage3a_best), f'best.pt が見つかりません: {stage3a_best}'

ckpt = torch.load(stage3a_last, map_location='cpu', weights_only=False)
print(f'Stage 3a last ckpt epoch: {ckpt["epoch"]}')
print(f'  student keys (先頭3): {list(ckpt["student"].keys())[:3]} ...')

ckpt_best = torch.load(stage3a_best, map_location='cpu', weights_only=False)
val_loss = ckpt_best.get('val_metrics', {}).get('val_loss', float('nan'))
print(f'Stage 3a best val_loss: {val_loss:.4f}')
print('Stage 3a 完了 ✓')
# Out:
# Stage 3a last ckpt epoch: 1000
#   student keys (先頭3): ['cls_token', 'cls_pos', 'encoder.first_conv.0.weight'] ...
# Stage 3a best val_loss: 0.6607
# Stage 3a 完了 ✓

# %% [markdown]
# ## Step 10 — Stage 3b 学習 (局所パッチ BCE + KD + EWC、50 エポック)
#
# ```
# patch_feat (B, 128, 1280)
#  ↓ BCE (32 パッチ × 5 テキスト)
#  ↓ + λ_kd × MSE(student, teacher)
#  ↓ + λ_ewc × Σ F_i (θ_i - θ*_i)²
# ```
#
# > **出力**: `outputs/stage3b/checkpoints/best.pt` (Phase 4 Attribution へ入力)

# %%
# %cd {PHASE3_DIR}
# !python train_stage3b.py \
    --config    {CFG_3B_PATH} \
    --init_ckpt {STAGE3A_LAST}
# Out:
# /content/drive/MyDrive/2026研究/ULIP_PointLLM/DentalPatchAligned3D/Phase3_Training_v2
# /usr/local/lib/python3.12/dist-packages/timm/models/layers/__init__.py:49: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# 2026-04-21 13:31:56,621 INFO Config: {'seed': 42, 'output_dir': '/content/drive/MyDrive/2026研究/ULIP_PointLLM/DentalPatchAligned3D/Phase3_Training_v2/outputs/stage3b', 'data': {'ply_dir': '/content/drive/MyDrive/2026研究/Dataset/6167726/STLs/STLs/normPLYs', 'json_path': '/content/drive/MyDrive/2026研究/ULIP_PointLLM/data/DentalPatchData/dental_vocab/candidates.json', 'npoints': 2048, 'val_ratio': 0.2, 'text_augment': True}, 'clip': {'model': 'hf-hub:microsoft/BiomedCLIP-PubMedBERT_256-vit_base_patch16_224', 'pretrained': '', 'cache_capacity': 10000}, 'model': {'trans_dim': 384, 'depth': 12, 'drop_path_rate': 0.1, 'cls_dim': 50, 'num_heads': 6, 'group_size': 32, 'num_group': 128, 'encoder_dims': 256, 'color': False, 'num_classes': 16, 'clip_dim': 512, 'clip_tau': 0.07, 'stage2_ckpt': '/content/drive/MyDrive/2026研究/ULIP_PointLLM/checkpoints/patchalign3d/patchalign3d.pt'}, 'loss': {'lambda_bce': 1.0, 'lambda_kd': 0.0, 'lambda_ewc': 1.0, 'lambda_kd_text': 0.0, 'ewc_fisher_batches': 50}, 'training': {'epochs': 1000, 'batch_size': 1024, 'lr': 0.0001, 'weight_decay': 0.05, 'warmup_epochs': 5, 'num_workers': 2, 'eval_every': 5, 'save_every': 50}}
# 2026-04-21 13:31:56,622 INFO Device: cuda
# 2026-04-21 13:31:56,641 INFO Train: 16 患者  Val: 4 患者
# 2026-04-21 13:31:59,751 INFO NumExpr defaulting to 12 threads.
# 2026-04-21 13:32:00,462 INFO Parsing model identifier. Schema: hf-hub, Identifier: microsoft/BiomedCLIP-PubMedBERT_256-vit_base_patch16_224
# 2026-04-21 13:32:00,462 INFO Attempting to load config from HF Hub: microsoft/BiomedCLIP-PubMedBERT_256-vit_base_patch16_224
# 2026-04-21 13:32:00,622 INFO HTTP Request: HEAD https://huggingface.co/microsoft/BiomedCLIP-PubMedBERT_256-vit_base_patch16_224/resolve/main/open_clip_config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-04-21 13:32:00,638 INFO HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/microsoft/BiomedCLIP-PubMedBERT_256-vit_base_patch16_224/9f341de24bfb00180f1b847274256e9b65a3a32e/open_clip_config.json "HTTP/1.1 200 OK"
# 2026-04-21 13:32:00,639 INFO Loaded model config from HF Hub: microsoft/BiomedCLIP-PubMedBERT_256-vit_base_patch16_224
# 2026-04-21 13:32:00,686 INFO HTTP Request: HEAD https://huggingface.co/microsoft/BiomedCLIP-PubMedBERT_256-vit_base_patch16_224/resolve/main/open_clip_model.safetensors "HTTP/1.1 404 Not Found"
# 2026-04-21 13:32:00,742 INFO HTTP Request: HEAD https://huggingface.co/microsoft/BiomedCLIP-PubMedBERT_256-vit_base_patch16_224/resolve/main/open_clip_pytorch_model.bin "HTTP/1.1 302 Found"
# 2026-04-21 13:32:00,743 INFO Found default weights file on HF Hub: /root/.cache/huggingface/hub/models--microsoft--BiomedCLIP-PubMedBERT_256-vit_base_patch16_224/snapshots/9f341de24bfb00180f1b847274256e9b65a3a32e/open_clip_pytorch_model.bin
# 2026-04-21 13:32:00,744 INFO Instantiating model architecture: CustomTextCLIP
# 2026-04-21 13:32:01,896 INFO HTTP Request: HEAD https://huggingface.co/microsoft/BiomedNLP-BiomedBERT-base-uncased-abstract/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-04-21 13:32:01,918 INFO HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/microsoft/BiomedNLP-BiomedBERT-base-uncased-abstract/d673b8835373c6fa116d6d8006b33d48734e305d/config.json "HTTP/1.1 200 OK"
# 2026-04-21 13:32:03,420 INFO Loading full pretrained weights from: /root/.cache/huggingface/hub/models--microsoft--BiomedCLIP-PubMedBERT_256-vit_base_patch16_224/snapshots/9f341de24bfb00180f1b847274256e9b65a3a32e/open_clip_pytorch_model.bin
# 2026-04-21 13:32:03,981 INFO Final image preprocessing configuration set: {'size': (224, 224), 'mode': 'RGB', 'mean': [0.48145466, 0.4578275, 0.40821073], 'std': [0.26862954, 0.26130258, 0.27577711], 'interpolation': 'bicubic', 'resize_mode': 'shortest', 'fill_color': 0}
# 2026-04-21 13:32:03,981 INFO Model hf-hub:microsoft/BiomedCLIP-PubMedBERT_256-vit_base_patch16_224 creation process complete.
# 2026-04-21 13:32:04,500 INFO Parsing tokenizer identifier. Schema: hf-hub, Identifier: microsoft/BiomedCLIP-PubMedBERT_256-vit_base_patch16_224
# 2026-04-21 13:32:04,500 INFO Attempting to load config from hf-hub:microsoft/BiomedCLIP-PubMedBERT_256-vit_base_patch16_224
# 2026-04-21 13:32:04,550 INFO HTTP Request: HEAD https://huggingface.co/microsoft/BiomedCLIP-PubMedBERT_256-vit_base_patch16_224/resolve/main/open_clip_config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-04-21 13:32:04,565 INFO HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/microsoft/BiomedCLIP-PubMedBERT_256-vit_base_patch16_224/9f341de24bfb00180f1b847274256e9b65a3a32e/open_clip_config.json "HTTP/1.1 200 OK"
# 2026-04-21 13:32:04,566 INFO Using HFTokenizer with source: 'microsoft/BiomedNLP-BiomedBERT-base-uncased-abstract', mode: 'None'
# 2026-04-21 13:32:04,611 INFO HTTP Request: HEAD https://huggingface.co/microsoft/BiomedNLP-BiomedBERT-base-uncased-abstract/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-04-21 13:32:04,627 INFO HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/microsoft/BiomedNLP-BiomedBERT-base-uncased-abstract/d673b8835373c6fa116d6d8006b33d48734e305d/config.json "HTTP/1.1 200 OK"
# 2026-04-21 13:32:04,677 INFO HTTP Request: HEAD https://huggingface.co/microsoft/BiomedNLP-BiomedBERT-base-uncased-abstract/resolve/main/tokenizer_config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-04-21 13:32:04,692 INFO HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/microsoft/BiomedNLP-BiomedBERT-base-uncased-abstract/d673b8835373c6fa116d6d8006b33d48734e305d/tokenizer_config.json "HTTP/1.1 200 OK"
# 2026-04-21 13:32:04,743 INFO HTTP Request: GET https://huggingface.co/api/models/microsoft/BiomedNLP-BiomedBERT-base-uncased-abstract/tree/main/additional_chat_templates?recursive=false&expand=false "HTTP/1.1 404 Not Found"
# 2026-04-21 13:32:04,807 INFO HTTP Request: GET https://huggingface.co/api/models/microsoft/BiomedNLP-BiomedBERT-base-uncased-abstract/tree/main?recursive=true&expand=false "HTTP/1.1 200 OK"
# [TextCache] CLIP hf-hub:microsoft/BiomedCLIP-PubMedBERT_256-vit_base_patch16_224 をロード  テキスト次元: 512
# [Stage3] チェックポイントをロード: /content/drive/MyDrive/2026研究/ULIP_PointLLM/DentalPatchAligned3D/Phase3_Training_v2/outputs/stage3a/stage3a_last.pt
# [Stage3] Student: 学習可能 1,873,536 / 総 21,858,816 パラメータ  Proj: 197,120
# 2026-04-21 13:32:05,695 INFO モデルを初期化: init_ckpt=/content/drive/MyDrive/2026研究/ULIP_PointLLM/DentalPatchAligned3D/Phase3_Training_v2/outputs/stage3a/stage3a_last.pt
# 2026-04-21 13:32:05,718 INFO EWC Fisher をキャッシュからロード: /content/drive/MyDrive/2026研究/ULIP_PointLLM/DentalPatchAligned3D/Phase3_Training_v2/outputs/stage3b/ewc_fisher.pt
# 2026-04-21 13:32:05,739 INFO EWC を構築しました。
# 2026-04-21 13:32:11,741 INFO Epoch   1/1000  loss=1.5958  bce=1.5882  kd=0.0028  ewc=7.6309e-03  patch_acc=0.036  temp=14.29  lr=4.00e-05
# 2026-04-21 13:32:15,834 INFO Epoch   2/1000  loss=1.4572  bce=1.4496  kd=0.0028  ewc=7.6308e-03  patch_acc=0.022  temp=14.28  lr=6.00e-05
# 2026-04-21 13:32:19,260 INFO Epoch   3/1000  loss=1.3794  bce=1.3718  kd=0.0028  ewc=7.6307e-03  patch_acc=0.047  temp=14.28  lr=8.00e-05
# 2026-04-21 13:32:22,170 INFO Epoch   4/1000  loss=1.5633  bce=1.5556  kd=0.0028  ewc=7.6304e-03  patch_acc=0.040  temp=14.28  lr=1.00e-04
# 2026-04-21 13:32:24,685 INFO Epoch   5/1000  loss=1.5758  bce=1.5682  kd=0.0028  ewc=7.6301e-03  patch_acc=0.036  temp=14.28  lr=1.00e-04
# 2026-04-21 13:32:25,460 INFO   -> val_loss=1.4692  val_patch_acc=0.016
# 2026-04-21 13:32:26,082 INFO   -> Best チェックポイントを保存 (val_loss=1.4692)
# 2026-04-21 13:32:28,242 INFO Epoch   6/1000  loss=1.4209  bce=1.4133  kd=0.0027  ewc=7.6297e-03  patch_acc=0.022  temp=14.28  lr=1.00e-04
# 2026-04-21 13:32:30,311 INFO Epoch   7/1000  loss=1.3519  bce=1.3443  kd=0.0027  ewc=7.6294e-03  patch_acc=0.031  temp=14.28  lr=1.00e-04
# 2026-04-21 13:32:32,963 INFO Epoch   8/1000  loss=1.3879  bce=1.3803  kd=0.0027  ewc=7.6290e-03  patch_acc=0.039  temp=14.28  lr=1.00e-04
# 2026-04-21 13:32:34,442 INFO Epoch   9/1000  loss=1.4467  bce=1.4391  kd=0.0027  ewc=7.6287e-03  patch_acc=0.036  temp=14.28  lr=1.00e-04
# 2026-04-21 13:32:35,769 INFO Epoch  10/1000  loss=1.4212  bce=1.4136  kd=0.0027  ewc=7.6283e-03  patch_acc=0.034  temp=14.27  lr=1.00e-04
# 2026-04-21 13:32:35,900 INFO   -> val_loss=1.3700  val_patch_acc=0.016
# 2026-04-21 13:32:36,514 INFO   -> Best チェックポイントを保存 (val_loss=1.3700)
# 2026-04-21 13:32:38,244 INFO Epoch  11/1000  loss=1.3684  bce=1.3608  kd=0.0027  ewc=7.6280e-03  patch_acc=0.045  temp=14.27  lr=1.00e-04
# 2026-04-21 13:32:39,326 INFO Epoch  12/1000  loss=1.3391  bce=1.3314  kd=0.0027  ewc=7.6276e-03  patch_acc=0.026  temp=14.27  lr=1.00e-04
# 2026-04-21 13:32:40,337 INFO Epoch  13/1000  loss=1.3389  bce=1.3313  kd=0.0026  ewc=7.6272e-03  patch_acc=0.059  temp=14.27  lr=1.00e-04
# 2026-04-21 13:32:41,310 INFO Epoch  14/1000  loss=1.3548  bce=1.3471  kd=0.0026  ewc=7.6269e-03  patch_acc=0.046  temp=14.27  lr=1.00e-04
# 2026-04-21 13:32:42,243 INFO Epoch  15/1000  loss=1.3509  bce=1.3432  kd=0.0026  ewc=7.6265e-03  patch_acc=0.063  temp=14.27  lr=1.00e-04
# 2026-04-21 13:32:42,378 INFO   -> val_loss=1.3947  val_patch_acc=0.037
# 2026-04-21 13:32:43,653 INFO Epoch  16/1000  loss=1.3607  bce=1.3531  kd=0.0026  ewc=7.6262e-03  patch_acc=0.052  temp=14.27  lr=1.00e-04
# 2026-04-21 13:32:44,498 INFO Epoch  17/1000  loss=1.3453  bce=1.3377  kd=0.0026  ewc=7.6259e-03  patch_acc=0.041  temp=14.27  lr=1.00e-04
# 2026-04-21 13:32:45,310 INFO Epoch  18/1000  loss=1.3273  bce=1.3196  kd=0.0026  ewc=7.6255e-03  patch_acc=0.044  temp=14.27  lr=1.00e-04
# 2026-04-21 13:32:46,228 INFO Epoch  19/1000  loss=1.3196  bce=1.3120  kd=0.0026  ewc=7.6252e-03  patch_acc=0.042  temp=14.27  lr=9.99e-05
# 2026-04-21 13:32:48,014 INFO Epoch  20/1000  loss=1.3241  bce=1.3165  kd=0.0025  ewc=7.6249e-03  patch_acc=0.056  temp=14.27  lr=9.99e-05
# 2026-04-21 13:32:48,144 INFO   -> val_loss=1.3426  val_patch_acc=0.037
# 2026-04-21 13:32:48,772 INFO   -> Best チェックポイントを保存 (val_loss=1.3426)
# 2026-04-21 13:32:49,692 INFO Epoch  21/1000  loss=1.3173  bce=1.3097  kd=0.0025  ewc=7.6246e-03  patch_acc=0.040  temp=14.26  lr=9.99e-05
# 2026-04-21 13:32:50,536 INFO Epoch  22/1000  loss=1.3319  bce=1.3243  kd=0.0025  ewc=7.6243e-03  patch_acc=0.048  temp=14.26  lr=9.99e-05
# 2026-04-21 13:32:51,298 INFO Epoch  23/1000  loss=1.3322  bce=1.3246  kd=0.0025  ewc=7.6239e-03  patch_acc=0.044  temp=14.26  lr=9.99e-05
# 2026-04-21 13:32:52,097 INFO Epoch  24/1000  loss=1.3175  bce=1.3099  kd=0.0025  ewc=7.6236e-03  patch_acc=0.052  temp=14.26  lr=9.99e-05
# 2026-04-21 13:32:52,892 INFO Epoch  25/1000  loss=1.3195  bce=1.3119  kd=0.0025  ewc=7.6233e-03  patch_acc=0.033  temp=14.26  lr=9.99e-05
# 2026-04-21 13:32:53,033 INFO   -> val_loss=1.3399  val_patch_acc=0.037
# 2026-04-21 13:32:53,660 INFO   -> Best チェックポイントを保存 (val_loss=1.3399)
# 2026-04-21 13:32:54,436 INFO Epoch  26/1000  loss=1.3021  bce=1.2945  kd=0.0025  ewc=7.6229e-03  patch_acc=0.064  temp=14.26  lr=9.99e-05
# 2026-04-21 13:32:55,194 INFO Epoch  27/1000  loss=1.2981  bce=1.2904  kd=0.0025  ewc=7.6226e-03  patch_acc=0.073  temp=14.26  lr=9.99e-05
# 2026-04-21 13:32:55,946 INFO Epoch  28/1000  loss=1.3134  bce=1.3058  kd=0.0025  ewc=7.6223e-03  patch_acc=0.055  temp=14.26  lr=9.99e-05
# 2026-04-21 13:32:56,720 INFO Epoch  29/1000  loss=1.3145  bce=1.3069  kd=0.0025  ewc=7.6220e-03  patch_acc=0.051  temp=14.26  lr=9.98e-05
# 2026-04-21 13:32:57,486 INFO Epoch  30/1000  loss=1.3212  bce=1.3136  kd=0.0025  ewc=7.6216e-03  patch_acc=0.058  temp=14.26  lr=9.98e-05
# 2026-04-21 13:32:57,614 INFO   -> val_loss=1.3361  val_patch_acc=0.039
# 2026-04-21 13:32:58,257 INFO   -> Best チェックポイントを保存 (val_loss=1.3361)
# 2026-04-21 13:32:59,041 INFO Epoch  31/1000  loss=1.3119  bce=1.3043  kd=0.0025  ewc=7.6213e-03  patch_acc=0.039  temp=14.26  lr=9.98e-05
# 2026-04-21 13:32:59,840 INFO Epoch  32/1000  loss=1.3030  bce=1.2954  kd=0.0025  ewc=7.6210e-03  patch_acc=0.073  temp=14.26  lr=9.98e-05
# 2026-04-21 13:33:00,612 INFO Epoch  33/1000  loss=1.3008  bce=1.2932  kd=0.0025  ewc=7.6207e-03  patch_acc=0.065  temp=14.26  lr=9.98e-05
# 2026-04-21 13:33:01,357 INFO Epoch  34/1000  loss=1.2945  bce=1.2868  kd=0.0025  ewc=7.6204e-03  patch_acc=0.054  temp=14.26  lr=9.98e-05
# 2026-04-21 13:33:02,112 INFO Epoch  35/1000  loss=1.2990  bce=1.2913  kd=0.0025  ewc=7.6200e-03  patch_acc=0.062  temp=14.26  lr=9.98e-05
# 2026-04-21 13:33:02,246 INFO   -> val_loss=1.3252  val_patch_acc=0.039
# 2026-04-21 13:33:02,871 INFO   -> Best チェックポイントを保存 (val_loss=1.3252)
# 2026-04-21 13:33:04,175 INFO Epoch  36/1000  loss=1.3029  bce=1.2953  kd=0.0025  ewc=7.6197e-03  patch_acc=0.053  temp=14.26  lr=9.97e-05
# 2026-04-21 13:33:04,919 INFO Epoch  37/1000  loss=1.2942  bce=1.2866  kd=0.0024  ewc=7.6194e-03  patch_acc=0.045  temp=14.26  lr=9.97e-05
# 2026-04-21 13:33:05,679 INFO Epoch  38/1000  loss=1.3078  bce=1.3002  kd=0.0024  ewc=7.6191e-03  patch_acc=0.058  temp=14.26  lr=9.97e-05
# 2026-04-21 13:33:06,432 INFO Epoch  39/1000  loss=1.2844  bce=1.2768  kd=0.0024  ewc=7.6188e-03  patch_acc=0.061  temp=14.26  lr=9.97e-05
# 2026-04-21 13:33:07,175 INFO Epoch  40/1000  loss=1.2913  bce=1.2837  kd=0.0024  ewc=7.6184e-03  patch_acc=0.060  temp=14.26  lr=9.97e-05
# 2026-04-21 13:33:07,307 INFO   -> val_loss=1.3200  val_patch_acc=0.035
# 2026-04-21 13:33:07,926 INFO   -> Best チェックポイントを保存 (val_loss=1.3200)
# 2026-04-21 13:33:08,687 INFO Epoch  41/1000  loss=1.2928  bce=1.2852  kd=0.0024  ewc=7.6181e-03  patch_acc=0.048  temp=14.26  lr=9.97e-05
# 2026-04-21 13:33:09,446 INFO Epoch  42/1000  loss=1.2883  bce=1.2807  kd=0.0024  ewc=7.6178e-03  patch_acc=0.059  temp=14.26  lr=9.96e-05
# 2026-04-21 13:33:10,202 INFO Epoch  43/1000  loss=1.2925  bce=1.2849  kd=0.0024  ewc=7.6175e-03  patch_acc=0.059  temp=14.26  lr=9.96e-05
# 2026-04-21 13:33:10,954 INFO Epoch  44/1000  loss=1.2944  bce=1.2867  kd=0.0024  ewc=7.6172e-03  patch_acc=0.051  temp=14.26  lr=9.96e-05
# 2026-04-21 13:33:11,712 INFO Epoch  45/1000  loss=1.2872  bce=1.2796  kd=0.0024  ewc=7.6169e-03  patch_acc=0.071  temp=14.26  lr=9.96e-05
# 2026-04-21 13:33:11,846 INFO   -> val_loss=1.3094  val_patch_acc=0.020
# 2026-04-21 13:33:12,502 INFO   -> Best チェックポイントを保存 (val_loss=1.3094)
# 2026-04-21 13:33:13,810 INFO Epoch  46/1000  loss=1.2908  bce=1.2832  kd=0.0024  ewc=7.6165e-03  patch_acc=0.062  temp=14.26  lr=9.96e-05
# 2026-04-21 13:33:14,558 INFO Epoch  47/1000  loss=1.2851  bce=1.2775  kd=0.0024  ewc=7.6162e-03  patch_acc=0.062  temp=14.26  lr=9.95e-05
# 2026-04-21 13:33:15,299 INFO Epoch  48/1000  loss=1.2849  bce=1.2772  kd=0.0024  ewc=7.6159e-03  patch_acc=0.046  temp=14.26  lr=9.95e-05
# 2026-04-21 13:33:16,043 INFO Epoch  49/1000  loss=1.2821  bce=1.2745  kd=0.0024  ewc=7.6156e-03  patch_acc=0.066  temp=14.26  lr=9.95e-05
# 2026-04-21 13:33:16,786 INFO Epoch  50/1000  loss=1.2946  bce=1.2869  kd=0.0024  ewc=7.6153e-03  patch_acc=0.045  temp=14.26  lr=9.95e-05
# 2026-04-21 13:33:16,916 INFO   -> val_loss=1.3042  val_patch_acc=0.016
# 2026-04-21 13:33:17,548 INFO   -> Best チェックポイントを保存 (val_loss=1.3042)
# 2026-04-21 13:33:18,584 INFO Epoch  51/1000  loss=1.2849  bce=1.2773  kd=0.0024  ewc=7.6150e-03  patch_acc=0.078  temp=14.26  lr=9.95e-05
# 2026-04-21 13:33:19,395 INFO Epoch  52/1000  loss=1.2791  bce=1.2715  kd=0.0025  ewc=7.6147e-03  patch_acc=0.053  temp=14.26  lr=9.94e-05
# 2026-04-21 13:33:20,142 INFO Epoch  53/1000  loss=1.2796  bce=1.2720  kd=0.0025  ewc=7.6144e-03  patch_acc=0.064  temp=14.26  lr=9.94e-05
# 2026-04-21 13:33:20,881 INFO Epoch  54/1000  loss=1.2705  bce=1.2629  kd=0.0025  ewc=7.6141e-03  patch_acc=0.069  temp=14.26  lr=9.94e-05
# 2026-04-21 13:33:21,627 INFO Epoch  55/1000  loss=1.2692  bce=1.2616  kd=0.0024  ewc=7.6138e-03  patch_acc=0.077  temp=14.26  lr=9.94e-05
# 2026-04-21 13:33:21,755 INFO   -> val_loss=1.3006  val_patch_acc=0.016
# 2026-04-21 13:33:22,393 INFO   -> Best チェックポイントを保存 (val_loss=1.3006)
# 2026-04-21 13:33:23,709 INFO Epoch  56/1000  loss=1.2718  bce=1.2642  kd=0.0024  ewc=7.6135e-03  patch_acc=0.056  temp=14.26  lr=9.93e-05
# 2026-04-21 13:33:24,454 INFO Epoch  57/1000  loss=1.2712  bce=1.2636  kd=0.0025  ewc=7.6132e-03  patch_acc=0.065  temp=14.26  lr=9.93e-05
# 2026-04-21 13:33:25,231 INFO Epoch  58/1000  loss=1.2721  bce=1.2645  kd=0.0024  ewc=7.6129e-03  patch_acc=0.077  temp=14.26  lr=9.93e-05
# 2026-04-21 13:33:25,999 INFO Epoch  59/1000  loss=1.2682  bce=1.2606  kd=0.0025  ewc=7.6126e-03  patch_acc=0.057  temp=14.26  lr=9.92e-05
# 2026-04-21 13:33:26,751 INFO Epoch  60/1000  loss=1.2657  bce=1.2581  kd=0.0025  ewc=7.6124e-03  patch_acc=0.088  temp=14.26  lr=9.92e-05
# 2026-04-21 13:33:26,880 INFO   -> val_loss=1.2821  val_patch_acc=0.033
# 2026-04-21 13:33:28,291 INFO   -> Best チェックポイントを保存 (val_loss=1.2821)
# 2026-04-21 13:33:29,088 INFO Epoch  61/1000  loss=1.2628  bce=1.2552  kd=0.0025  ewc=7.6121e-03  patch_acc=0.062  temp=14.26  lr=9.92e-05
# 2026-04-21 13:33:30,230 INFO Epoch  62/1000  loss=1.2524  bce=1.2448  kd=0.0025  ewc=7.6118e-03  patch_acc=0.066  temp=14.26  lr=9.92e-05
# 2026-04-21 13:33:30,984 INFO Epoch  63/1000  loss=1.2590  bce=1.2514  kd=0.0025  ewc=7.6116e-03  patch_acc=0.077  temp=14.26  lr=9.91e-05
# 2026-04-21 13:33:31,727 INFO Epoch  64/1000  loss=1.2522  bce=1.2446  kd=0.0025  ewc=7.6113e-03  patch_acc=0.079  temp=14.26  lr=9.91e-05
# 2026-04-21 13:33:32,468 INFO Epoch  65/1000  loss=1.2489  bce=1.2413  kd=0.0025  ewc=7.6111e-03  patch_acc=0.086  temp=14.26  lr=9.91e-05
# 2026-04-21 13:33:32,609 INFO   -> val_loss=1.2644  val_patch_acc=0.037
# 2026-04-21 13:33:33,252 INFO   -> Best チェックポイントを保存 (val_loss=1.2644)
# 2026-04-21 13:33:34,014 INFO Epoch  66/1000  loss=1.2399  bce=1.2323  kd=0.0025  ewc=7.6108e-03  patch_acc=0.080  temp=14.26  lr=9.90e-05
# 2026-04-21 13:33:34,800 INFO Epoch  67/1000  loss=1.2574  bce=1.2498  kd=0.0025  ewc=7.6106e-03  patch_acc=0.073  temp=14.26  lr=9.90e-05
# 2026-04-21 13:33:35,559 INFO Epoch  68/1000  loss=1.2486  bce=1.2410  kd=0.0025  ewc=7.6104e-03  patch_acc=0.092  temp=14.26  lr=9.90e-05
# 2026-04-21 13:33:36,312 INFO Epoch  69/1000  loss=1.2347  bce=1.2270  kd=0.0025  ewc=7.6102e-03  patch_acc=0.096  temp=14.26  lr=9.90e-05
# 2026-04-21 13:33:37,096 INFO Epoch  70/1000  loss=1.2312  bce=1.2236  kd=0.0025  ewc=7.6100e-03  patch_acc=0.091  temp=14.26  lr=9.89e-05
# 2026-04-21 13:33:37,227 INFO   -> val_loss=1.2377  val_patch_acc=0.045
# 2026-04-21 13:33:37,862 INFO   -> Best チェックポイントを保存 (val_loss=1.2377)
# 2026-04-21 13:33:39,180 INFO Epoch  71/1000  loss=1.2195  bce=1.2119  kd=0.0025  ewc=7.6099e-03  patch_acc=0.096  temp=14.26  lr=9.89e-05
# 2026-04-21 13:33:39,928 INFO Epoch  72/1000  loss=1.2289  bce=1.2213  kd=0.0025  ewc=7.6097e-03  patch_acc=0.091  temp=14.26  lr=9.89e-05
# 2026-04-21 13:33:40,673 INFO Epoch  73/1000  loss=1.2173  bce=1.2097  kd=0.0026  ewc=7.6096e-03  patch_acc=0.086  temp=14.26  lr=9.88e-05
# 2026-04-21 13:33:41,421 INFO Epoch  74/1000  loss=1.2173  bce=1.2097  kd=0.0026  ewc=7.6094e-03  patch_acc=0.082  temp=14.26  lr=9.88e-05
# 2026-04-21 13:33:42,182 INFO Epoch  75/1000  loss=1.2063  bce=1.1987  kd=0.0026  ewc=7.6093e-03  patch_acc=0.094  temp=14.26  lr=9.87e-05
# 2026-04-21 13:33:42,315 INFO   -> val_loss=1.1860  val_patch_acc=0.078
# 2026-04-21 13:33:43,009 INFO   -> Best チェックポイントを保存 (val_loss=1.1860)
# 2026-04-21 13:33:43,760 INFO Epoch  76/1000  loss=1.1906  bce=1.1830  kd=0.0026  ewc=7.6092e-03  patch_acc=0.120  temp=14.26  lr=9.87e-05
# 2026-04-21 13:33:45,022 INFO Epoch  77/1000  loss=1.1921  bce=1.1845  kd=0.0026  ewc=7.6092e-03  patch_acc=0.114  temp=14.26  lr=9.87e-05
# 2026-04-21 13:33:45,767 INFO Epoch  78/1000  loss=1.1812  bce=1.1736  kd=0.0027  ewc=7.6091e-03  patch_acc=0.087  temp=14.26  lr=9.86e-05
# 2026-04-21 13:33:46,511 INFO Epoch  79/1000  loss=1.1721  bce=1.1645  kd=0.0027  ewc=7.6091e-03  patch_acc=0.087  temp=14.26  lr=9.86e-05
# 2026-04-21 13:33:47,272 INFO Epoch  80/1000  loss=1.1691  bce=1.1615  kd=0.0027  ewc=7.6091e-03  patch_acc=0.102  temp=14.27  lr=9.86e-05
# 2026-04-21 13:33:47,405 INFO   -> val_loss=1.1310  val_patch_acc=0.102
# 2026-04-21 13:33:48,021 INFO   -> Best チェックポイントを保存 (val_loss=1.1310)
# 2026-04-21 13:33:48,782 INFO Epoch  81/1000  loss=1.1429  bce=1.1353  kd=0.0028  ewc=7.6091e-03  patch_acc=0.107  temp=14.27  lr=9.85e-05
# 2026-04-21 13:33:49,547 INFO Epoch  82/1000  loss=1.1462  bce=1.1385  kd=0.0028  ewc=7.6092e-03  patch_acc=0.124  temp=14.27  lr=9.85e-05
# 2026-04-21 13:33:50,306 INFO Epoch  83/1000  loss=1.1210  bce=1.1134  kd=0.0029  ewc=7.6092e-03  patch_acc=0.113  temp=14.27  lr=9.85e-05
# 2026-04-21 13:33:51,072 INFO Epoch  84/1000  loss=1.1308  bce=1.1232  kd=0.0029  ewc=7.6093e-03  patch_acc=0.123  temp=14.27  lr=9.84e-05
# 2026-04-21 13:33:51,832 INFO Epoch  85/1000  loss=1.1083  bce=1.1007  kd=0.0029  ewc=7.6093e-03  patch_acc=0.115  temp=14.27  lr=9.84e-05
# 2026-04-21 13:33:51,962 INFO   -> val_loss=1.0754  val_patch_acc=0.146
# 2026-04-21 13:33:52,583 INFO   -> Best チェックポイントを保存 (val_loss=1.0754)
# 2026-04-21 13:33:53,905 INFO Epoch  86/1000  loss=1.1199  bce=1.1123  kd=0.0029  ewc=7.6094e-03  patch_acc=0.107  temp=14.27  lr=9.83e-05
# 2026-04-21 13:33:54,664 INFO Epoch  87/1000  loss=1.1154  bce=1.1078  kd=0.0031  ewc=7.6094e-03  patch_acc=0.125  temp=14.27  lr=9.83e-05
# 2026-04-21 13:33:55,410 INFO Epoch  88/1000  loss=1.0780  bce=1.0704  kd=0.0031  ewc=7.6094e-03  patch_acc=0.121  temp=14.27  lr=9.83e-05
# 2026-04-21 13:33:56,165 INFO Epoch  89/1000  loss=1.0810  bce=1.0734  kd=0.0031  ewc=7.6095e-03  patch_acc=0.135  temp=14.27  lr=9.82e-05
# 2026-04-21 13:33:56,918 INFO Epoch  90/1000  loss=1.0925  bce=1.0849  kd=0.0032  ewc=7.6095e-03  patch_acc=0.108  temp=14.27  lr=9.82e-05
# 2026-04-21 13:33:57,049 INFO   -> val_loss=1.0323  val_patch_acc=0.139
# 2026-04-21 13:33:57,813 INFO   -> Best チェックポイントを保存 (val_loss=1.0323)
# 2026-04-21 13:33:58,582 INFO Epoch  91/1000  loss=1.0883  bce=1.0807  kd=0.0032  ewc=7.6095e-03  patch_acc=0.089  temp=14.27  lr=9.81e-05
# 2026-04-21 13:33:59,678 INFO Epoch  92/1000  loss=1.0571  bce=1.0495  kd=0.0033  ewc=7.6095e-03  patch_acc=0.123  temp=14.28  lr=9.81e-05
# 2026-04-21 13:34:00,437 INFO Epoch  93/1000  loss=1.0877  bce=1.0801  kd=0.0033  ewc=7.6095e-03  patch_acc=0.126  temp=14.28  lr=9.80e-05
# 2026-04-21 13:34:01,186 INFO Epoch  94/1000  loss=1.0753  bce=1.0677  kd=0.0034  ewc=7.6094e-03  patch_acc=0.125  temp=14.28  lr=9.80e-05
# 2026-04-21 13:34:01,945 INFO Epoch  95/1000  loss=1.0369  bce=1.0293  kd=0.0034  ewc=7.6093e-03  patch_acc=0.126  temp=14.28  lr=9.80e-05
# 2026-04-21 13:34:02,077 INFO   -> val_loss=1.0331  val_patch_acc=0.133
# 2026-04-21 13:34:03,427 INFO Epoch  96/1000  loss=1.0791  bce=1.0715  kd=0.0034  ewc=7.6092e-03  patch_acc=0.115  temp=14.28  lr=9.79e-05
# 2026-04-21 13:34:04,200 INFO Epoch  97/1000  loss=1.0405  bce=1.0329  kd=0.0035  ewc=7.6090e-03  patch_acc=0.108  temp=14.28  lr=9.79e-05
# 2026-04-21 13:34:04,951 INFO Epoch  98/1000  loss=1.0422  bce=1.0346  kd=0.0034  ewc=7.6089e-03  patch_acc=0.124  temp=14.28  lr=9.78e-05
# 2026-04-21 13:34:05,705 INFO Epoch  99/1000  loss=1.0318  bce=1.0242  kd=0.0034  ewc=7.6087e-03  patch_acc=0.117  temp=14.28  lr=9.78e-05
# 2026-04-21 13:34:06,446 INFO Epoch 100/1000  loss=1.0735  bce=1.0658  kd=0.0033  ewc=7.6085e-03  patch_acc=0.115  temp=14.28  lr=9.77e-05
# 2026-04-21 13:34:06,574 INFO   -> val_loss=1.0013  val_patch_acc=0.145
# 2026-04-21 13:34:08,534 INFO   -> Best チェックポイントを保存 (val_loss=1.0013)
# 2026-04-21 13:34:09,553 INFO Epoch 101/1000  loss=1.0586  bce=1.0510  kd=0.0034  ewc=7.6084e-03  patch_acc=0.110  temp=14.28  lr=9.77e-05
# 2026-04-21 13:34:10,811 INFO Epoch 102/1000  loss=1.0405  bce=1.0329  kd=0.0034  ewc=7.6082e-03  patch_acc=0.136  temp=14.28  lr=9.76e-05
# 2026-04-21 13:34:11,553 INFO Epoch 103/1000  loss=1.0384  bce=1.0308  kd=0.0034  ewc=7.6080e-03  patch_acc=0.122  temp=14.28  lr=9.76e-05
# 2026-04-21 13:34:12,317 INFO Epoch 104/1000  loss=1.0260  bce=1.0184  kd=0.0033  ewc=7.6079e-03  patch_acc=0.124  temp=14.28  lr=9.75e-05
# 2026-04-21 13:34:13,066 INFO Epoch 105/1000  loss=1.0470  bce=1.0394  kd=0.0034  ewc=7.6077e-03  patch_acc=0.146  temp=14.29  lr=9.75e-05
# 2026-04-21 13:34:13,195 INFO   -> val_loss=0.9835  val_patch_acc=0.141
# 2026-04-21 13:34:13,835 INFO   -> Best チェックポイントを保存 (val_loss=0.9835)
# 2026-04-21 13:34:15,419 INFO Epoch 106/1000  loss=1.0154  bce=1.0078  kd=0.0035  ewc=7.6075e-03  patch_acc=0.136  temp=14.29  lr=9.74e-05
# 2026-04-21 13:34:16,177 INFO Epoch 107/1000  loss=1.0236  bce=1.0160  kd=0.0035  ewc=7.6073e-03  patch_acc=0.134  temp=14.29  lr=9.74e-05
# 2026-04-21 13:34:16,949 INFO Epoch 108/1000  loss=1.0154  bce=1.0078  kd=0.0033  ewc=7.6071e-03  patch_acc=0.141  temp=14.29  lr=9.73e-05
# 2026-04-21 13:34:18,449 INFO Epoch 109/1000  loss=1.0226  bce=1.0150  kd=0.0034  ewc=7.6070e-03  patch_acc=0.126  temp=14.29  lr=9.73e-05
# 2026-04-21 13:34:19,203 INFO Epoch 110/1000  loss=1.0397  bce=1.0321  kd=0.0033  ewc=7.6068e-03  patch_acc=0.130  temp=14.29  lr=9.72e-05
# 2026-04-21 13:34:19,334 INFO   -> val_loss=0.9747  val_patch_acc=0.131
# 2026-04-21 13:34:19,960 INFO   -> Best チェックポイントを保存 (val_loss=0.9747)
# 2026-04-21 13:34:20,725 INFO Epoch 111/1000  loss=1.0093  bce=1.0017  kd=0.0034  ewc=7.6066e-03  patch_acc=0.131  temp=14.29  lr=9.72e-05
# 2026-04-21 13:34:21,472 INFO Epoch 112/1000  loss=1.0168  bce=1.0092  kd=0.0034  ewc=7.6064e-03  patch_acc=0.129  temp=14.29  lr=9.71e-05
# 2026-04-21 13:34:22,229 INFO Epoch 113/1000  loss=1.0101  bce=1.0025  kd=0.0034  ewc=7.6062e-03  patch_acc=0.146  temp=14.29  lr=9.71e-05
# 2026-04-21 13:34:22,978 INFO Epoch 114/1000  loss=1.0106  bce=1.0030  kd=0.0033  ewc=7.6061e-03  patch_acc=0.152  temp=14.29  lr=9.70e-05
# 2026-04-21 13:34:23,725 INFO Epoch 115/1000  loss=1.0023  bce=0.9947  kd=0.0035  ewc=7.6059e-03  patch_acc=0.137  temp=14.29  lr=9.70e-05
# 2026-04-21 13:34:23,854 INFO   -> val_loss=0.9799  val_patch_acc=0.113
# 2026-04-21 13:34:25,177 INFO Epoch 116/1000  loss=0.9965  bce=0.9889  kd=0.0035  ewc=7.6057e-03  patch_acc=0.134  temp=14.29  lr=9.69e-05
# 2026-04-21 13:34:25,937 INFO Epoch 117/1000  loss=1.0344  bce=1.0268  kd=0.0033  ewc=7.6055e-03  patch_acc=0.142  temp=14.29  lr=9.69e-05
# 2026-04-21 13:34:26,694 INFO Epoch 118/1000  loss=0.9837  bce=0.9761  kd=0.0034  ewc=7.6053e-03  patch_acc=0.153  temp=14.30  lr=9.68e-05
# 2026-04-21 13:34:28,598 INFO Epoch 119/1000  loss=1.0100  bce=1.0024  kd=0.0034  ewc=7.6052e-03  patch_acc=0.147  temp=14.30  lr=9.67e-05
# 2026-04-21 13:34:29,388 INFO Epoch 120/1000  loss=1.0044  bce=0.9968  kd=0.0033  ewc=7.6050e-03  patch_acc=0.127  temp=14.30  lr=9.67e-05
# 2026-04-21 13:34:29,521 INFO   -> val_loss=0.9767  val_patch_acc=0.109
# 2026-04-21 13:34:30,572 INFO Epoch 121/1000  loss=1.0162  bce=1.0086  kd=0.0033  ewc=7.6048e-03  patch_acc=0.123  temp=14.30  lr=9.66e-05
# 2026-04-21 13:34:31,318 INFO Epoch 122/1000  loss=0.9898  bce=0.9822  kd=0.0035  ewc=7.6047e-03  patch_acc=0.133  temp=14.30  lr=9.66e-05
# 2026-04-21 13:34:32,058 INFO Epoch 123/1000  loss=1.0278  bce=1.0202  kd=0.0034  ewc=7.6045e-03  patch_acc=0.123  temp=14.30  lr=9.65e-05
# 2026-04-21 13:34:32,798 INFO Epoch 124/1000  loss=0.9698  bce=0.9622  kd=0.0035  ewc=7.6044e-03  patch_acc=0.151  temp=14.30  lr=9.65e-05
# 2026-04-21 13:34:33,537 INFO Epoch 125/1000  loss=0.9963  bce=0.9887  kd=0.0035  ewc=7.6042e-03  patch_acc=0.147  temp=14.30  lr=9.64e-05
# 2026-04-21 13:34:33,680 INFO   -> val_loss=0.9593  val_patch_acc=0.104
# 2026-04-21 13:34:34,299 INFO   -> Best チェックポイントを保存 (val_loss=0.9593)
# 2026-04-21 13:34:35,054 INFO Epoch 126/1000  loss=0.9818  bce=0.9742  kd=0.0035  ewc=7.6040e-03  patch_acc=0.151  temp=14.30  lr=9.63e-05
# 2026-04-21 13:34:35,807 INFO Epoch 127/1000  loss=0.9782  bce=0.9706  kd=0.0035  ewc=7.6039e-03  patch_acc=0.149  temp=14.31  lr=9.63e-05
# 2026-04-21 13:34:36,576 INFO Epoch 128/1000  loss=0.9841  bce=0.9765  kd=0.0035  ewc=7.6037e-03  patch_acc=0.140  temp=14.31  lr=9.62e-05
# 2026-04-21 13:34:37,326 INFO Epoch 129/1000  loss=0.9730  bce=0.9654  kd=0.0035  ewc=7.6035e-03  patch_acc=0.154  temp=14.31  lr=9.62e-05
# 2026-04-21 13:34:38,079 INFO Epoch 130/1000  loss=0.9758  bce=0.9682  kd=0.0035  ewc=7.6034e-03  patch_acc=0.185  temp=14.31  lr=9.61e-05
# 2026-04-21 13:34:38,211 INFO   -> val_loss=0.9332  val_patch_acc=0.131
# 2026-04-21 13:34:38,920 INFO   -> Best チェックポイントを保存 (val_loss=0.9332)
# 2026-04-21 13:34:40,232 INFO Epoch 131/1000  loss=0.9653  bce=0.9577  kd=0.0035  ewc=7.6032e-03  patch_acc=0.141  temp=14.31  lr=9.60e-05
# 2026-04-21 13:34:40,995 INFO Epoch 132/1000  loss=0.9611  bce=0.9535  kd=0.0036  ewc=7.6030e-03  patch_acc=0.149  temp=14.31  lr=9.60e-05
# 2026-04-21 13:34:41,747 INFO Epoch 133/1000  loss=0.9646  bce=0.9570  kd=0.0036  ewc=7.6029e-03  patch_acc=0.145  temp=14.31  lr=9.59e-05
# 2026-04-21 13:34:42,510 INFO Epoch 134/1000  loss=0.9774  bce=0.9698  kd=0.0035  ewc=7.6027e-03  patch_acc=0.146  temp=14.31  lr=9.58e-05
# 2026-04-21 13:34:43,259 INFO Epoch 135/1000  loss=0.9660  bce=0.9584  kd=0.0037  ewc=7.6026e-03  patch_acc=0.125  temp=14.31  lr=9.58e-05
# 2026-04-21 13:34:43,392 INFO   -> val_loss=0.9204  val_patch_acc=0.135
# 2026-04-21 13:34:44,025 INFO   -> Best チェックポイントを保存 (val_loss=0.9204)
# 2026-04-21 13:34:44,769 INFO Epoch 136/1000  loss=0.9559  bce=0.9483  kd=0.0036  ewc=7.6024e-03  patch_acc=0.149  temp=14.32  lr=9.57e-05
# 2026-04-21 13:34:46,035 INFO Epoch 137/1000  loss=0.9637  bce=0.9561  kd=0.0037  ewc=7.6022e-03  patch_acc=0.149  temp=14.32  lr=9.57e-05
# 2026-04-21 13:34:46,785 INFO Epoch 138/1000  loss=0.9971  bce=0.9895  kd=0.0036  ewc=7.6020e-03  patch_acc=0.135  temp=14.32  lr=9.56e-05
# 2026-04-21 13:34:47,527 INFO Epoch 139/1000  loss=0.9664  bce=0.9588  kd=0.0036  ewc=7.6019e-03  patch_acc=0.154  temp=14.32  lr=9.55e-05
# 2026-04-21 13:34:48,280 INFO Epoch 140/1000  loss=0.9639  bce=0.9563  kd=0.0035  ewc=7.6017e-03  patch_acc=0.147  temp=14.32  lr=9.55e-05
# 2026-04-21 13:34:48,415 INFO   -> val_loss=0.9072  val_patch_acc=0.129
# 2026-04-21 13:34:49,034 INFO   -> Best チェックポイントを保存 (val_loss=0.9072)
# 2026-04-21 13:34:49,788 INFO Epoch 141/1000  loss=0.9476  bce=0.9400  kd=0.0035  ewc=7.6015e-03  patch_acc=0.159  temp=14.32  lr=9.54e-05
# 2026-04-21 13:34:50,536 INFO Epoch 142/1000  loss=0.9608  bce=0.9532  kd=0.0036  ewc=7.6014e-03  patch_acc=0.135  temp=14.32  lr=9.53e-05
# 2026-04-21 13:34:51,295 INFO Epoch 143/1000  loss=0.9397  bce=0.9321  kd=0.0036  ewc=7.6012e-03  patch_acc=0.148  temp=14.33  lr=9.53e-05
# 2026-04-21 13:34:52,057 INFO Epoch 144/1000  loss=0.9464  bce=0.9388  kd=0.0036  ewc=7.6010e-03  patch_acc=0.151  temp=14.33  lr=9.52e-05
# 2026-04-21 13:34:52,816 INFO Epoch 145/1000  loss=0.9486  bce=0.9410  kd=0.0037  ewc=7.6009e-03  patch_acc=0.163  temp=14.33  lr=9.51e-05
# 2026-04-21 13:34:52,949 INFO   -> val_loss=0.8968  val_patch_acc=0.117
# 2026-04-21 13:34:53,575 INFO   -> Best チェックポイントを保存 (val_loss=0.8968)
# 2026-04-21 13:34:54,340 INFO Epoch 146/1000  loss=0.9168  bce=0.9092  kd=0.0037  ewc=7.6007e-03  patch_acc=0.168  temp=14.33  lr=9.51e-05
# 2026-04-21 13:34:55,616 INFO Epoch 147/1000  loss=0.9282  bce=0.9206  kd=0.0037  ewc=7.6006e-03  patch_acc=0.154  temp=14.33  lr=9.50e-05
# 2026-04-21 13:34:56,364 INFO Epoch 148/1000  loss=0.9767  bce=0.9691  kd=0.0036  ewc=7.6004e-03  patch_acc=0.137  temp=14.33  lr=9.49e-05
# 2026-04-21 13:34:57,108 INFO Epoch 149/1000  loss=0.9163  bce=0.9087  kd=0.0037  ewc=7.6003e-03  patch_acc=0.164  temp=14.33  lr=9.49e-05
# 2026-04-21 13:34:57,862 INFO Epoch 150/1000  loss=0.9595  bce=0.9519  kd=0.0036  ewc=7.6001e-03  patch_acc=0.153  temp=14.34  lr=9.48e-05
# 2026-04-21 13:34:57,994 INFO   -> val_loss=0.8962  val_patch_acc=0.127
# 2026-04-21 13:34:58,645 INFO   -> Best チェックポイントを保存 (val_loss=0.8962)
# 2026-04-21 13:34:59,722 INFO Epoch 151/1000  loss=0.9571  bce=0.9495  kd=0.0035  ewc=7.6000e-03  patch_acc=0.161  temp=14.34  lr=9.47e-05
# 2026-04-21 13:35:00,465 INFO Epoch 152/1000  loss=0.9269  bce=0.9193  kd=0.0036  ewc=7.5999e-03  patch_acc=0.181  temp=14.34  lr=9.46e-05
# 2026-04-21 13:35:01,220 INFO Epoch 153/1000  loss=0.9343  bce=0.9267  kd=0.0037  ewc=7.5997e-03  patch_acc=0.169  temp=14.34  lr=9.46e-05
# 2026-04-21 13:35:01,973 INFO Epoch 154/1000  loss=0.9339  bce=0.9263  kd=0.0036  ewc=7.5996e-03  patch_acc=0.144  temp=14.34  lr=9.45e-05
# 2026-04-21 13:35:02,729 INFO Epoch 155/1000  loss=0.9343  bce=0.9267  kd=0.0035  ewc=7.5994e-03  patch_acc=0.184  temp=14.34  lr=9.44e-05
# 2026-04-21 13:35:02,858 INFO   -> val_loss=0.8974  val_patch_acc=0.127
# 2026-04-21 13:35:03,915 INFO Epoch 156/1000  loss=0.9433  bce=0.9357  kd=0.0035  ewc=7.5993e-03  patch_acc=0.168  temp=14.34  lr=9.44e-05
# 2026-04-21 13:35:04,922 INFO Epoch 157/1000  loss=0.9025  bce=0.8949  kd=0.0035  ewc=7.5992e-03  patch_acc=0.180  temp=14.35  lr=9.43e-05
# 2026-04-21 13:35:05,689 INFO Epoch 158/1000  loss=0.9244  bce=0.9168  kd=0.0037  ewc=7.5990e-03  patch_acc=0.165  temp=14.35  lr=9.42e-05
# 2026-04-21 13:35:06,451 INFO Epoch 159/1000  loss=0.9243  bce=0.9167  kd=0.0035  ewc=7.5989e-03  patch_acc=0.160  temp=14.35  lr=9.41e-05
# 2026-04-21 13:35:08,236 INFO Epoch 160/1000  loss=0.9657  bce=0.9581  kd=0.0036  ewc=7.5988e-03  patch_acc=0.153  temp=14.35  lr=9.41e-05
# 2026-04-21 13:35:08,369 INFO   -> val_loss=0.8791  val_patch_acc=0.125
# 2026-04-21 13:35:10,155 INFO   -> Best チェックポイントを保存 (val_loss=0.8791)
# 2026-04-21 13:35:10,948 INFO Epoch 161/1000  loss=0.8950  bce=0.8874  kd=0.0037  ewc=7.5986e-03  patch_acc=0.181  temp=14.35  lr=9.40e-05
# 2026-04-21 13:35:11,702 INFO Epoch 162/1000  loss=0.9078  bce=0.9002  kd=0.0037  ewc=7.5985e-03  patch_acc=0.177  temp=14.35  lr=9.39e-05
# 2026-04-21 13:35:12,447 INFO Epoch 163/1000  loss=0.9375  bce=0.9299  kd=0.0037  ewc=7.5983e-03  patch_acc=0.174  temp=14.35  lr=9.38e-05
# 2026-04-21 13:35:13,208 INFO Epoch 164/1000  loss=0.9233  bce=0.9157  kd=0.0037  ewc=7.5982e-03  patch_acc=0.167  temp=14.36  lr=9.38e-05
# 2026-04-21 13:35:13,952 INFO Epoch 165/1000  loss=0.9422  bce=0.9346  kd=0.0037  ewc=7.5980e-03  patch_acc=0.171  temp=14.36  lr=9.37e-05
# 2026-04-21 13:35:14,084 INFO   -> val_loss=0.8746  val_patch_acc=0.119
# 2026-04-21 13:35:14,705 INFO   -> Best チェックポイントを保存 (val_loss=0.8746)
# 2026-04-21 13:35:15,456 INFO Epoch 166/1000  loss=0.9040  bce=0.8964  kd=0.0036  ewc=7.5979e-03  patch_acc=0.173  temp=14.36  lr=9.36e-05
# 2026-04-21 13:35:16,724 INFO Epoch 167/1000  loss=0.9004  bce=0.8928  kd=0.0037  ewc=7.5977e-03  patch_acc=0.193  temp=14.36  lr=9.35e-05
# 2026-04-21 13:35:17,469 INFO Epoch 168/1000  loss=0.9083  bce=0.9007  kd=0.0036  ewc=7.5975e-03  patch_acc=0.154  temp=14.36  lr=9.34e-05
# 2026-04-21 13:35:18,214 INFO Epoch 169/1000  loss=0.9176  bce=0.9100  kd=0.0036  ewc=7.5973e-03  patch_acc=0.163  temp=14.36  lr=9.34e-05
# 2026-04-21 13:35:18,982 INFO Epoch 170/1000  loss=0.8806  bce=0.8730  kd=0.0036  ewc=7.5972e-03  patch_acc=0.184  temp=14.37  lr=9.33e-05
# 2026-04-21 13:35:19,118 INFO   -> val_loss=0.8715  val_patch_acc=0.125
# 2026-04-21 13:35:19,773 INFO   -> Best チェックポイントを保存 (val_loss=0.8715)
# 2026-04-21 13:35:20,534 INFO Epoch 171/1000  loss=0.9024  bce=0.8948  kd=0.0037  ewc=7.5970e-03  patch_acc=0.171  temp=14.37  lr=9.32e-05
# 2026-04-21 13:35:21,288 INFO Epoch 172/1000  loss=0.9102  bce=0.9026  kd=0.0037  ewc=7.5968e-03  patch_acc=0.148  temp=14.37  lr=9.31e-05
# 2026-04-21 13:35:22,852 INFO Epoch 173/1000  loss=0.8876  bce=0.8800  kd=0.0036  ewc=7.5967e-03  patch_acc=0.173  temp=14.37  lr=9.30e-05
# 2026-04-21 13:35:23,613 INFO Epoch 174/1000  loss=0.8953  bce=0.8877  kd=0.0037  ewc=7.5965e-03  patch_acc=0.146  temp=14.37  lr=9.30e-05
# 2026-04-21 13:35:24,352 INFO Epoch 175/1000  loss=0.8870  bce=0.8794  kd=0.0038  ewc=7.5963e-03  patch_acc=0.178  temp=14.37  lr=9.29e-05
# 2026-04-21 13:35:24,485 INFO   -> val_loss=0.8506  val_patch_acc=0.141
# 2026-04-21 13:35:25,135 INFO   -> Best チェックポイントを保存 (val_loss=0.8506)
# 2026-04-21 13:35:26,443 INFO Epoch 176/1000  loss=0.8838  bce=0.8762  kd=0.0037  ewc=7.5962e-03  patch_acc=0.187  temp=14.37  lr=9.28e-05
# 2026-04-21 13:35:27,187 INFO Epoch 177/1000  loss=0.9226  bce=0.9150  kd=0.0036  ewc=7.5960e-03  patch_acc=0.167  temp=14.38  lr=9.27e-05
# 2026-04-21 13:35:27,944 INFO Epoch 178/1000  loss=0.8646  bce=0.8570  kd=0.0038  ewc=7.5959e-03  patch_acc=0.182  temp=14.38  lr=9.26e-05
# 2026-04-21 13:35:28,717 INFO Epoch 179/1000  loss=0.9081  bce=0.9005  kd=0.0036  ewc=7.5957e-03  patch_acc=0.170  temp=14.38  lr=9.26e-05
# 2026-04-21 13:35:29,476 INFO Epoch 180/1000  loss=0.8902  bce=0.8826  kd=0.0037  ewc=7.5955e-03  patch_acc=0.204  temp=14.38  lr=9.25e-05
# 2026-04-21 13:35:29,612 INFO   -> val_loss=0.8510  val_patch_acc=0.139
# 2026-04-21 13:35:30,693 INFO Epoch 181/1000  loss=0.8989  bce=0.8913  kd=0.0037  ewc=7.5954e-03  patch_acc=0.171  temp=14.38  lr=9.24e-05
# 2026-04-21 13:35:31,745 INFO Epoch 182/1000  loss=0.8762  bce=0.8686  kd=0.0038  ewc=7.5952e-03  patch_acc=0.163  temp=14.38  lr=9.23e-05
# 2026-04-21 13:35:33,677 INFO Epoch 183/1000  loss=0.8738  bce=0.8662  kd=0.0038  ewc=7.5951e-03  patch_acc=0.182  temp=14.39  lr=9.22e-05
# 2026-04-21 13:35:35,256 INFO Epoch 184/1000  loss=0.8837  bce=0.8761  kd=0.0037  ewc=7.5949e-03  patch_acc=0.185  temp=14.39  lr=9.21e-05
# 2026-04-21 13:35:36,031 INFO Epoch 185/1000  loss=0.8902  bce=0.8826  kd=0.0037  ewc=7.5947e-03  patch_acc=0.182  temp=14.39  lr=9.21e-05
# 2026-04-21 13:35:36,178 INFO   -> val_loss=0.8473  val_patch_acc=0.137
# 2026-04-21 13:35:36,835 INFO   -> Best チェックポイントを保存 (val_loss=0.8473)
# 2026-04-21 13:35:37,611 INFO Epoch 186/1000  loss=0.9056  bce=0.8980  kd=0.0037  ewc=7.5946e-03  patch_acc=0.159  temp=14.39  lr=9.20e-05
# 2026-04-21 13:35:38,371 INFO Epoch 187/1000  loss=0.9092  bce=0.9016  kd=0.0037  ewc=7.5944e-03  patch_acc=0.164  temp=14.39  lr=9.19e-05
# 2026-04-21 13:35:39,148 INFO Epoch 188/1000  loss=0.8816  bce=0.8740  kd=0.0038  ewc=7.5942e-03  patch_acc=0.170  temp=14.39  lr=9.18e-05
# 2026-04-21 13:35:39,902 INFO Epoch 189/1000  loss=0.8648  bce=0.8572  kd=0.0037  ewc=7.5941e-03  patch_acc=0.192  temp=14.40  lr=9.17e-05
# 2026-04-21 13:35:40,672 INFO Epoch 190/1000  loss=0.9104  bce=0.9028  kd=0.0036  ewc=7.5939e-03  patch_acc=0.168  temp=14.40  lr=9.16e-05
# 2026-04-21 13:35:40,805 INFO   -> val_loss=0.8296  val_patch_acc=0.150
# 2026-04-21 13:35:41,453 INFO   -> Best チェックポイントを保存 (val_loss=0.8296)
# 2026-04-21 13:35:42,769 INFO Epoch 191/1000  loss=0.8486  bce=0.8410  kd=0.0037  ewc=7.5937e-03  patch_acc=0.183  temp=14.40  lr=9.15e-05
# 2026-04-21 13:35:43,521 INFO Epoch 192/1000  loss=0.8922  bce=0.8846  kd=0.0036  ewc=7.5935e-03  patch_acc=0.191  temp=14.40  lr=9.14e-05
# 2026-04-21 13:35:44,289 INFO Epoch 193/1000  loss=0.8629  bce=0.8553  kd=0.0037  ewc=7.5934e-03  patch_acc=0.190  temp=14.40  lr=9.14e-05
# 2026-04-21 13:35:45,059 INFO Epoch 194/1000  loss=0.8671  bce=0.8595  kd=0.0037  ewc=7.5932e-03  patch_acc=0.207  temp=14.40  lr=9.13e-05
# 2026-04-21 13:35:45,846 INFO Epoch 195/1000  loss=0.8979  bce=0.8903  kd=0.0036  ewc=7.5930e-03  patch_acc=0.167  temp=14.41  lr=9.12e-05
# 2026-04-21 13:35:45,979 INFO   -> val_loss=0.8398  val_patch_acc=0.148
# 2026-04-21 13:35:47,076 INFO Epoch 196/1000  loss=0.8817  bce=0.8741  kd=0.0037  ewc=7.5928e-03  patch_acc=0.181  temp=14.41  lr=9.11e-05
# 2026-04-21 13:35:47,841 INFO Epoch 197/1000  loss=0.8714  bce=0.8638  kd=0.0037  ewc=7.5926e-03  patch_acc=0.206  temp=14.41  lr=9.10e-05
# 2026-04-21 13:35:50,955 INFO Epoch 198/1000  loss=0.9019  bce=0.8943  kd=0.0036  ewc=7.5925e-03  patch_acc=0.154  temp=14.41  lr=9.09e-05
# 2026-04-21 13:35:51,728 INFO Epoch 199/1000  loss=0.8793  bce=0.8717  kd=0.0036  ewc=7.5923e-03  patch_acc=0.181  temp=14.41  lr=9.08e-05
# 2026-04-21 13:35:52,496 INFO Epoch 200/1000  loss=0.8848  bce=0.8772  kd=0.0036  ewc=7.5921e-03  patch_acc=0.153  temp=14.41  lr=9.07e-05
# 2026-04-21 13:35:52,631 INFO   -> val_loss=0.8388  val_patch_acc=0.150
# 2026-04-21 13:35:54,012 INFO Epoch 201/1000  loss=0.8540  bce=0.8464  kd=0.0037  ewc=7.5919e-03  patch_acc=0.205  temp=14.41  lr=9.06e-05
# 2026-04-21 13:35:54,781 INFO Epoch 202/1000  loss=0.8772  bce=0.8696  kd=0.0035  ewc=7.5918e-03  patch_acc=0.169  temp=14.42  lr=9.05e-05
# 2026-04-21 13:35:55,533 INFO Epoch 203/1000  loss=0.8969  bce=0.8893  kd=0.0036  ewc=7.5916e-03  patch_acc=0.170  temp=14.42  lr=9.05e-05
# 2026-04-21 13:35:56,592 INFO Epoch 204/1000  loss=0.8856  bce=0.8780  kd=0.0037  ewc=7.5914e-03  patch_acc=0.188  temp=14.42  lr=9.04e-05
# 2026-04-21 13:35:57,360 INFO Epoch 205/1000  loss=0.8580  bce=0.8504  kd=0.0037  ewc=7.5913e-03  patch_acc=0.166  temp=14.42  lr=9.03e-05
# 2026-04-21 13:35:57,494 INFO   -> val_loss=0.8404  val_patch_acc=0.160
# 2026-04-21 13:35:58,587 INFO Epoch 206/1000  loss=0.8605  bce=0.8529  kd=0.0036  ewc=7.5911e-03  patch_acc=0.174  temp=14.42  lr=9.02e-05
# 2026-04-21 13:35:59,343 INFO Epoch 207/1000  loss=0.8576  bce=0.8501  kd=0.0037  ewc=7.5909e-03  patch_acc=0.215  temp=14.42  lr=9.01e-05
# 2026-04-21 13:36:00,104 INFO Epoch 208/1000  loss=0.8401  bce=0.8325  kd=0.0037  ewc=7.5907e-03  patch_acc=0.205  temp=14.43  lr=9.00e-05
# 2026-04-21 13:36:00,844 INFO Epoch 209/1000  loss=0.8697  bce=0.8621  kd=0.0037  ewc=7.5905e-03  patch_acc=0.205  temp=14.43  lr=8.99e-05
# 2026-04-21 13:36:01,597 INFO Epoch 210/1000  loss=0.8465  bce=0.8389  kd=0.0037  ewc=7.5903e-03  patch_acc=0.193  temp=14.43  lr=8.98e-05
# 2026-04-21 13:36:01,729 INFO   -> val_loss=0.8167  val_patch_acc=0.154
# 2026-04-21 13:36:02,360 INFO   -> Best チェックポイントを保存 (val_loss=0.8167)
# 2026-04-21 13:36:03,968 INFO Epoch 211/1000  loss=0.8680  bce=0.8604  kd=0.0037  ewc=7.5901e-03  patch_acc=0.185  temp=14.43  lr=8.97e-05
# 2026-04-21 13:36:04,715 INFO Epoch 212/1000  loss=0.8611  bce=0.8535  kd=0.0037  ewc=7.5899e-03  patch_acc=0.186  temp=14.43  lr=8.96e-05
# 2026-04-21 13:36:05,459 INFO Epoch 213/1000  loss=0.8611  bce=0.8535  kd=0.0037  ewc=7.5897e-03  patch_acc=0.163  temp=14.43  lr=8.95e-05
# 2026-04-21 13:36:06,208 INFO Epoch 214/1000  loss=0.8640  bce=0.8564  kd=0.0036  ewc=7.5895e-03  patch_acc=0.173  temp=14.43  lr=8.94e-05
# 2026-04-21 13:36:06,975 INFO Epoch 215/1000  loss=0.8579  bce=0.8503  kd=0.0036  ewc=7.5893e-03  patch_acc=0.183  temp=14.44  lr=8.93e-05
# 2026-04-21 13:36:07,107 INFO   -> val_loss=0.8198  val_patch_acc=0.152
# 2026-04-21 13:36:08,170 INFO Epoch 216/1000  loss=0.8764  bce=0.8688  kd=0.0037  ewc=7.5891e-03  patch_acc=0.171  temp=14.44  lr=8.92e-05
# 2026-04-21 13:36:08,924 INFO Epoch 217/1000  loss=0.8538  bce=0.8462  kd=0.0037  ewc=7.5889e-03  patch_acc=0.181  temp=14.44  lr=8.91e-05
# 2026-04-21 13:36:09,928 INFO Epoch 218/1000  loss=0.8771  bce=0.8695  kd=0.0036  ewc=7.5888e-03  patch_acc=0.184  temp=14.44  lr=8.90e-05
# 2026-04-21 13:36:10,685 INFO Epoch 219/1000  loss=0.8369  bce=0.8293  kd=0.0038  ewc=7.5886e-03  patch_acc=0.174  temp=14.44  lr=8.89e-05
# 2026-04-21 13:36:11,432 INFO Epoch 220/1000  loss=0.8749  bce=0.8673  kd=0.0036  ewc=7.5884e-03  patch_acc=0.185  temp=14.44  lr=8.88e-05
# 2026-04-21 13:36:11,565 INFO   -> val_loss=0.8225  val_patch_acc=0.139
# 2026-04-21 13:36:13,628 INFO Epoch 221/1000  loss=0.8701  bce=0.8625  kd=0.0037  ewc=7.5882e-03  patch_acc=0.175  temp=14.45  lr=8.87e-05
# 2026-04-21 13:36:14,400 INFO Epoch 222/1000  loss=0.8535  bce=0.8459  kd=0.0037  ewc=7.5880e-03  patch_acc=0.175  temp=14.45  lr=8.86e-05
# 2026-04-21 13:36:15,144 INFO Epoch 223/1000  loss=0.8655  bce=0.8579  kd=0.0037  ewc=7.5878e-03  patch_acc=0.183  temp=14.45  lr=8.85e-05
# 2026-04-21 13:36:15,889 INFO Epoch 224/1000  loss=0.8426  bce=0.8350  kd=0.0038  ewc=7.5876e-03  patch_acc=0.164  temp=14.45  lr=8.84e-05
# 2026-04-21 13:36:16,645 INFO Epoch 225/1000  loss=0.8678  bce=0.8602  kd=0.0037  ewc=7.5874e-03  patch_acc=0.187  temp=14.45  lr=8.83e-05
# 2026-04-21 13:36:16,784 INFO   -> val_loss=0.8074  val_patch_acc=0.152
# 2026-04-21 13:36:17,398 INFO   -> Best チェックポイントを保存 (val_loss=0.8074)
# 2026-04-21 13:36:18,149 INFO Epoch 226/1000  loss=0.8388  bce=0.8312  kd=0.0037  ewc=7.5872e-03  patch_acc=0.180  temp=14.45  lr=8.82e-05
# 2026-04-21 13:36:18,897 INFO Epoch 227/1000  loss=0.8510  bce=0.8435  kd=0.0036  ewc=7.5870e-03  patch_acc=0.188  temp=14.46  lr=8.81e-05
# 2026-04-21 13:36:20,168 INFO Epoch 228/1000  loss=0.8397  bce=0.8321  kd=0.0037  ewc=7.5868e-03  patch_acc=0.201  temp=14.46  lr=8.80e-05
# 2026-04-21 13:36:20,920 INFO Epoch 229/1000  loss=0.8259  bce=0.8183  kd=0.0037  ewc=7.5866e-03  patch_acc=0.192  temp=14.46  lr=8.79e-05
# 2026-04-21 13:36:21,661 INFO Epoch 230/1000  loss=0.8342  bce=0.8266  kd=0.0038  ewc=7.5864e-03  patch_acc=0.208  temp=14.46  lr=8.78e-05
# 2026-04-21 13:36:21,795 INFO   -> val_loss=0.8130  val_patch_acc=0.170
# 2026-04-21 13:36:23,115 INFO Epoch 231/1000  loss=0.8559  bce=0.8483  kd=0.0037  ewc=7.5862e-03  patch_acc=0.167  temp=14.46  lr=8.77e-05
# 2026-04-21 13:36:23,885 INFO Epoch 232/1000  loss=0.8513  bce=0.8437  kd=0.0037  ewc=7.5860e-03  patch_acc=0.184  temp=14.46  lr=8.76e-05
# 2026-04-21 13:36:24,654 INFO Epoch 233/1000  loss=0.8586  bce=0.8511  kd=0.0037  ewc=7.5858e-03  patch_acc=0.208  temp=14.46  lr=8.75e-05
# 2026-04-21 13:36:25,413 INFO Epoch 234/1000  loss=0.8290  bce=0.8214  kd=0.0037  ewc=7.5857e-03  patch_acc=0.208  temp=14.47  lr=8.74e-05
# 2026-04-21 13:36:26,167 INFO Epoch 235/1000  loss=0.8435  bce=0.8359  kd=0.0037  ewc=7.5855e-03  patch_acc=0.178  temp=14.47  lr=8.73e-05
# 2026-04-21 13:36:26,301 INFO   -> val_loss=0.8167  val_patch_acc=0.168
# 2026-04-21 13:36:27,380 INFO Epoch 236/1000  loss=0.8535  bce=0.8460  kd=0.0037  ewc=7.5853e-03  patch_acc=0.183  temp=14.47  lr=8.72e-05
# 2026-04-21 13:36:29,254 INFO Epoch 237/1000  loss=0.8187  bce=0.8111  kd=0.0038  ewc=7.5851e-03  patch_acc=0.186  temp=14.47  lr=8.71e-05
# 2026-04-21 13:36:30,013 INFO Epoch 238/1000  loss=0.8563  bce=0.8488  kd=0.0037  ewc=7.5849e-03  patch_acc=0.166  temp=14.47  lr=8.70e-05
# 2026-04-21 13:36:30,755 INFO Epoch 239/1000  loss=0.8273  bce=0.8197  kd=0.0037  ewc=7.5847e-03  patch_acc=0.217  temp=14.47  lr=8.69e-05
# 2026-04-21 13:36:31,500 INFO Epoch 240/1000  loss=0.8498  bce=0.8422  kd=0.0037  ewc=7.5845e-03  patch_acc=0.190  temp=14.48  lr=8.67e-05
# 2026-04-21 13:36:31,629 INFO   -> val_loss=0.8039  val_patch_acc=0.172
# 2026-04-21 13:36:32,296 INFO   -> Best チェックポイントを保存 (val_loss=0.8039)
# 2026-04-21 13:36:33,591 INFO Epoch 241/1000  loss=0.8210  bce=0.8134  kd=0.0037  ewc=7.5843e-03  patch_acc=0.204  temp=14.48  lr=8.66e-05
# 2026-04-21 13:36:34,346 INFO Epoch 242/1000  loss=0.8546  bce=0.8471  kd=0.0037  ewc=7.5841e-03  patch_acc=0.201  temp=14.48  lr=8.65e-05
# 2026-04-21 13:36:35,119 INFO Epoch 243/1000  loss=0.8663  bce=0.8588  kd=0.0036  ewc=7.5839e-03  patch_acc=0.196  temp=14.48  lr=8.64e-05
# 2026-04-21 13:36:35,896 INFO Epoch 244/1000  loss=0.8575  bce=0.8500  kd=0.0037  ewc=7.5837e-03  patch_acc=0.171  temp=14.48  lr=8.63e-05
# 2026-04-21 13:36:36,654 INFO Epoch 245/1000  loss=0.8059  bce=0.7983  kd=0.0037  ewc=7.5835e-03  patch_acc=0.219  temp=14.48  lr=8.62e-05
# 2026-04-21 13:36:36,786 INFO   -> val_loss=0.8031  val_patch_acc=0.164
# 2026-04-21 13:36:37,432 INFO   -> Best チェックポイントを保存 (val_loss=0.8031)
# 2026-04-21 13:36:38,190 INFO Epoch 246/1000  loss=0.8366  bce=0.8290  kd=0.0037  ewc=7.5833e-03  patch_acc=0.185  temp=14.48  lr=8.61e-05
# 2026-04-21 13:36:39,471 INFO Epoch 247/1000  loss=0.8227  bce=0.8151  kd=0.0037  ewc=7.5831e-03  patch_acc=0.205  temp=14.49  lr=8.60e-05
# 2026-04-21 13:36:40,223 INFO Epoch 248/1000  loss=0.8077  bce=0.8001  kd=0.0037  ewc=7.5829e-03  patch_acc=0.187  temp=14.49  lr=8.59e-05
# 2026-04-21 13:36:40,980 INFO Epoch 249/1000  loss=0.8247  bce=0.8171  kd=0.0037  ewc=7.5827e-03  patch_acc=0.216  temp=14.49  lr=8.58e-05
# 2026-04-21 13:36:41,721 INFO Epoch 250/1000  loss=0.8501  bce=0.8425  kd=0.0036  ewc=7.5825e-03  patch_acc=0.215  temp=14.49  lr=8.57e-05
# 2026-04-21 13:36:41,852 INFO   -> val_loss=0.7942  val_patch_acc=0.156
# 2026-04-21 13:36:42,569 INFO   -> Best チェックポイントを保存 (val_loss=0.7942)
# 2026-04-21 13:36:43,555 INFO Epoch 251/1000  loss=0.8493  bce=0.8417  kd=0.0037  ewc=7.5823e-03  patch_acc=0.190  temp=14.49  lr=8.56e-05
# 2026-04-21 13:36:44,307 INFO Epoch 252/1000  loss=0.8395  bce=0.8320  kd=0.0037  ewc=7.5821e-03  patch_acc=0.180  temp=14.49  lr=8.54e-05
# 2026-04-21 13:36:45,070 INFO Epoch 253/1000  loss=0.8247  bce=0.8171  kd=0.0037  ewc=7.5819e-03  patch_acc=0.207  temp=14.50  lr=8.53e-05
# ...
# 2026-04-21 13:47:08,346 INFO Epoch 898/1000  loss=0.7288  bce=0.7213  kd=0.0037  ewc=7.5065e-03  patch_acc=0.264  temp=14.91  lr=2.52e-06
# 2026-04-21 13:47:09,118 INFO Epoch 899/1000  loss=0.7390  bce=0.7315  kd=0.0037  ewc=7.5065e-03  patch_acc=0.237  temp=14.91  lr=2.47e-06
# 2026-04-21 13:47:09,895 INFO Epoch 900/1000  loss=0.7325  bce=0.7250  kd=0.0037  ewc=7.5065e-03  patch_acc=0.256  temp=14.91  lr=2.42e-06
# 2026-04-21 13:47:10,025 INFO   -> val_loss=0.7395  val_patch_acc=0.207
# 2026-04-21 13:47:11,377 INFO Epoch 901/1000  loss=0.7282  bce=0.7207  kd=0.0038  ewc=7.5065e-03  patch_acc=0.258  temp=14.91  lr=2.37e-06
# 2026-04-21 13:47:12,597 INFO Epoch 902/1000  loss=0.7406  bce=0.7331  kd=0.0037  ewc=7.5065e-03  patch_acc=0.268  temp=14.91  lr=2.33e-06
# 2026-04-21 13:47:13,350 INFO Epoch 903/1000  loss=0.7554  bce=0.7479  kd=0.0037  ewc=7.5065e-03  patch_acc=0.241  temp=14.91  lr=2.28e-06
# 2026-04-21 13:47:14,104 INFO Epoch 904/1000  loss=0.7767  bce=0.7692  kd=0.0037  ewc=7.5065e-03  patch_acc=0.235  temp=14.91  lr=2.23e-06
# 2026-04-21 13:47:14,848 INFO Epoch 905/1000  loss=0.7556  bce=0.7481  kd=0.0037  ewc=7.5065e-03  patch_acc=0.214  temp=14.91  lr=2.19e-06
# 2026-04-21 13:47:14,990 INFO   -> val_loss=0.7393  val_patch_acc=0.199
# 2026-04-21 13:47:16,044 INFO Epoch 906/1000  loss=0.7176  bce=0.7101  kd=0.0037  ewc=7.5065e-03  patch_acc=0.240  temp=14.91  lr=2.14e-06
# 2026-04-21 13:47:16,794 INFO Epoch 907/1000  loss=0.7706  bce=0.7631  kd=0.0037  ewc=7.5064e-03  patch_acc=0.199  temp=14.91  lr=2.09e-06
# 2026-04-21 13:47:17,555 INFO Epoch 908/1000  loss=0.7410  bce=0.7335  kd=0.0037  ewc=7.5064e-03  patch_acc=0.259  temp=14.91  lr=2.05e-06
# 2026-04-21 13:47:18,859 INFO Epoch 909/1000  loss=0.7590  bce=0.7515  kd=0.0037  ewc=7.5064e-03  patch_acc=0.244  temp=14.91  lr=2.01e-06
# 2026-04-21 13:47:19,617 INFO Epoch 910/1000  loss=0.7283  bce=0.7208  kd=0.0037  ewc=7.5064e-03  patch_acc=0.216  temp=14.91  lr=1.96e-06
# 2026-04-21 13:47:19,744 INFO   -> val_loss=0.7392  val_patch_acc=0.207
# 2026-04-21 13:47:20,784 INFO Epoch 911/1000  loss=0.7698  bce=0.7623  kd=0.0037  ewc=7.5064e-03  patch_acc=0.242  temp=14.91  lr=1.92e-06
# 2026-04-21 13:47:21,762 INFO Epoch 912/1000  loss=0.7386  bce=0.7311  kd=0.0037  ewc=7.5064e-03  patch_acc=0.229  temp=14.91  lr=1.87e-06
# 2026-04-21 13:47:22,518 INFO Epoch 913/1000  loss=0.7583  bce=0.7508  kd=0.0037  ewc=7.5064e-03  patch_acc=0.229  temp=14.91  lr=1.83e-06
# 2026-04-21 13:47:23,277 INFO Epoch 914/1000  loss=0.7373  bce=0.7298  kd=0.0037  ewc=7.5064e-03  patch_acc=0.227  temp=14.91  lr=1.79e-06
# 2026-04-21 13:47:24,040 INFO Epoch 915/1000  loss=0.7429  bce=0.7353  kd=0.0037  ewc=7.5064e-03  patch_acc=0.239  temp=14.91  lr=1.75e-06
# 2026-04-21 13:47:24,168 INFO   -> val_loss=0.7402  val_patch_acc=0.215
# 2026-04-21 13:47:25,265 INFO Epoch 916/1000  loss=0.7440  bce=0.7365  kd=0.0037  ewc=7.5064e-03  patch_acc=0.266  temp=14.91  lr=1.71e-06
# 2026-04-21 13:47:26,016 INFO Epoch 917/1000  loss=0.7545  bce=0.7470  kd=0.0037  ewc=7.5064e-03  patch_acc=0.257  temp=14.91  lr=1.67e-06
# 2026-04-21 13:47:26,985 INFO Epoch 918/1000  loss=0.7577  bce=0.7502  kd=0.0037  ewc=7.5064e-03  patch_acc=0.248  temp=14.91  lr=1.63e-06
# 2026-04-21 13:47:27,728 INFO Epoch 919/1000  loss=0.7139  bce=0.7064  kd=0.0037  ewc=7.5064e-03  patch_acc=0.249  temp=14.91  lr=1.59e-06
# 2026-04-21 13:47:28,489 INFO Epoch 920/1000  loss=0.7397  bce=0.7322  kd=0.0037  ewc=7.5064e-03  patch_acc=0.256  temp=14.91  lr=1.55e-06
# 2026-04-21 13:47:28,618 INFO   -> val_loss=0.7408  val_patch_acc=0.213
# 2026-04-21 13:47:29,887 INFO Epoch 921/1000  loss=0.7511  bce=0.7436  kd=0.0037  ewc=7.5063e-03  patch_acc=0.255  temp=14.91  lr=1.51e-06
# 2026-04-21 13:47:30,630 INFO Epoch 922/1000  loss=0.7457  bce=0.7382  kd=0.0037  ewc=7.5063e-03  patch_acc=0.221  temp=14.91  lr=1.47e-06
# 2026-04-21 13:47:31,374 INFO Epoch 923/1000  loss=0.7516  bce=0.7441  kd=0.0037  ewc=7.5063e-03  patch_acc=0.229  temp=14.91  lr=1.43e-06
# 2026-04-21 13:47:32,125 INFO Epoch 924/1000  loss=0.7516  bce=0.7441  kd=0.0037  ewc=7.5063e-03  patch_acc=0.245  temp=14.91  lr=1.40e-06
# 2026-04-21 13:47:32,889 INFO Epoch 925/1000  loss=0.7397  bce=0.7322  kd=0.0037  ewc=7.5063e-03  patch_acc=0.259  temp=14.91  lr=1.36e-06
# 2026-04-21 13:47:33,021 INFO   -> val_loss=0.7402  val_patch_acc=0.213
# 2026-04-21 13:47:34,078 INFO Epoch 926/1000  loss=0.7301  bce=0.7225  kd=0.0037  ewc=7.5063e-03  patch_acc=0.251  temp=14.91  lr=1.32e-06
# 2026-04-21 13:47:34,826 INFO Epoch 927/1000  loss=0.7524  bce=0.7449  kd=0.0037  ewc=7.5063e-03  patch_acc=0.257  temp=14.91  lr=1.29e-06
# 2026-04-21 13:47:35,819 INFO Epoch 928/1000  loss=0.7318  bce=0.7243  kd=0.0038  ewc=7.5063e-03  patch_acc=0.258  temp=14.91  lr=1.25e-06
# 2026-04-21 13:47:36,588 INFO Epoch 929/1000  loss=0.7469  bce=0.7394  kd=0.0037  ewc=7.5063e-03  patch_acc=0.252  temp=14.91  lr=1.22e-06
# 2026-04-21 13:47:37,328 INFO Epoch 930/1000  loss=0.7174  bce=0.7099  kd=0.0037  ewc=7.5063e-03  patch_acc=0.267  temp=14.91  lr=1.18e-06
# 2026-04-21 13:47:37,459 INFO   -> val_loss=0.7394  val_patch_acc=0.205
# 2026-04-21 13:47:38,743 INFO Epoch 931/1000  loss=0.7236  bce=0.7161  kd=0.0037  ewc=7.5063e-03  patch_acc=0.249  temp=14.91  lr=1.15e-06
# 2026-04-21 13:47:39,495 INFO Epoch 932/1000  loss=0.7576  bce=0.7501  kd=0.0037  ewc=7.5063e-03  patch_acc=0.258  temp=14.91  lr=1.11e-06
# 2026-04-21 13:47:40,245 INFO Epoch 933/1000  loss=0.7493  bce=0.7417  kd=0.0037  ewc=7.5063e-03  patch_acc=0.257  temp=14.91  lr=1.08e-06
# 2026-04-21 13:47:41,004 INFO Epoch 934/1000  loss=0.7533  bce=0.7458  kd=0.0038  ewc=7.5063e-03  patch_acc=0.225  temp=14.91  lr=1.05e-06
# 2026-04-21 13:47:41,765 INFO Epoch 935/1000  loss=0.7441  bce=0.7366  kd=0.0037  ewc=7.5063e-03  patch_acc=0.244  temp=14.91  lr=1.02e-06
# 2026-04-21 13:47:41,894 INFO   -> val_loss=0.7393  val_patch_acc=0.205
# 2026-04-21 13:47:42,965 INFO Epoch 936/1000  loss=0.7529  bce=0.7454  kd=0.0037  ewc=7.5063e-03  patch_acc=0.257  temp=14.91  lr=9.86e-07
# 2026-04-21 13:47:43,742 INFO Epoch 937/1000  loss=0.7714  bce=0.7639  kd=0.0037  ewc=7.5063e-03  patch_acc=0.235  temp=14.91  lr=9.55e-07
# 2026-04-21 13:47:44,483 INFO Epoch 938/1000  loss=0.7627  bce=0.7552  kd=0.0037  ewc=7.5063e-03  patch_acc=0.220  temp=14.91  lr=9.25e-07
# 2026-04-21 13:47:45,235 INFO Epoch 939/1000  loss=0.7223  bce=0.7148  kd=0.0037  ewc=7.5063e-03  patch_acc=0.249  temp=14.91  lr=8.95e-07
# 2026-04-21 13:47:45,973 INFO Epoch 940/1000  loss=0.7537  bce=0.7462  kd=0.0037  ewc=7.5063e-03  patch_acc=0.247  temp=14.91  lr=8.65e-07
# 2026-04-21 13:47:46,104 INFO   -> val_loss=0.7394  val_patch_acc=0.205
# 2026-04-21 13:47:47,438 INFO Epoch 941/1000  loss=0.7343  bce=0.7268  kd=0.0037  ewc=7.5063e-03  patch_acc=0.258  temp=14.91  lr=8.36e-07
# 2026-04-21 13:47:48,188 INFO Epoch 942/1000  loss=0.7464  bce=0.7389  kd=0.0037  ewc=7.5062e-03  patch_acc=0.262  temp=14.91  lr=8.08e-07
# 2026-04-21 13:47:48,956 INFO Epoch 943/1000  loss=0.7267  bce=0.7192  kd=0.0037  ewc=7.5062e-03  patch_acc=0.258  temp=14.91  lr=7.80e-07
# 2026-04-21 13:47:49,711 INFO Epoch 944/1000  loss=0.7302  bce=0.7227  kd=0.0037  ewc=7.5062e-03  patch_acc=0.232  temp=14.91  lr=7.52e-07
# 2026-04-21 13:47:50,464 INFO Epoch 945/1000  loss=0.7465  bce=0.7390  kd=0.0037  ewc=7.5062e-03  patch_acc=0.237  temp=14.91  lr=7.25e-07
# 2026-04-21 13:47:50,592 INFO   -> val_loss=0.7393  val_patch_acc=0.209
# 2026-04-21 13:47:51,700 INFO Epoch 946/1000  loss=0.7526  bce=0.7451  kd=0.0037  ewc=7.5062e-03  patch_acc=0.264  temp=14.91  lr=6.98e-07
# 2026-04-21 13:47:52,690 INFO Epoch 947/1000  loss=0.7131  bce=0.7056  kd=0.0037  ewc=7.5062e-03  patch_acc=0.283  temp=14.91  lr=6.72e-07
# 2026-04-21 13:47:53,447 INFO Epoch 948/1000  loss=0.7351  bce=0.7276  kd=0.0037  ewc=7.5062e-03  patch_acc=0.238  temp=14.91  lr=6.47e-07
# 2026-04-21 13:47:54,183 INFO Epoch 949/1000  loss=0.7405  bce=0.7330  kd=0.0037  ewc=7.5062e-03  patch_acc=0.230  temp=14.91  lr=6.22e-07
# 2026-04-21 13:47:54,936 INFO Epoch 950/1000  loss=0.7227  bce=0.7152  kd=0.0037  ewc=7.5062e-03  patch_acc=0.262  temp=14.91  lr=5.97e-07
# 2026-04-21 13:47:55,079 INFO   -> val_loss=0.7391  val_patch_acc=0.205
# 2026-04-21 13:47:56,382 INFO Epoch 951/1000  loss=0.7182  bce=0.7107  kd=0.0037  ewc=7.5062e-03  patch_acc=0.257  temp=14.91  lr=5.73e-07
# 2026-04-21 13:47:57,133 INFO Epoch 952/1000  loss=0.7524  bce=0.7449  kd=0.0037  ewc=7.5062e-03  patch_acc=0.262  temp=14.91  lr=5.50e-07
# 2026-04-21 13:47:57,876 INFO Epoch 953/1000  loss=0.7530  bce=0.7454  kd=0.0037  ewc=7.5062e-03  patch_acc=0.232  temp=14.91  lr=5.26e-07
# 2026-04-21 13:47:58,618 INFO Epoch 954/1000  loss=0.7308  bce=0.7233  kd=0.0037  ewc=7.5062e-03  patch_acc=0.250  temp=14.91  lr=5.04e-07
# 2026-04-21 13:47:59,365 INFO Epoch 955/1000  loss=0.7462  bce=0.7387  kd=0.0037  ewc=7.5062e-03  patch_acc=0.254  temp=14.91  lr=4.82e-07
# 2026-04-21 13:47:59,495 INFO   -> val_loss=0.7391  val_patch_acc=0.205
# 2026-04-21 13:48:00,569 INFO Epoch 956/1000  loss=0.7470  bce=0.7394  kd=0.0037  ewc=7.5062e-03  patch_acc=0.212  temp=14.91  lr=4.60e-07
# 2026-04-21 13:48:01,564 INFO Epoch 957/1000  loss=0.7676  bce=0.7601  kd=0.0037  ewc=7.5062e-03  patch_acc=0.252  temp=14.91  lr=4.39e-07
# 2026-04-21 13:48:02,317 INFO Epoch 958/1000  loss=0.7302  bce=0.7227  kd=0.0037  ewc=7.5062e-03  patch_acc=0.252  temp=14.91  lr=4.18e-07
# 2026-04-21 13:48:03,063 INFO Epoch 959/1000  loss=0.7415  bce=0.7340  kd=0.0037  ewc=7.5062e-03  patch_acc=0.236  temp=14.91  lr=3.98e-07
# 2026-04-21 13:48:04,628 INFO Epoch 960/1000  loss=0.7330  bce=0.7255  kd=0.0037  ewc=7.5062e-03  patch_acc=0.266  temp=14.91  lr=3.79e-07
# 2026-04-21 13:48:04,756 INFO   -> val_loss=0.7393  val_patch_acc=0.207
# 2026-04-21 13:48:05,803 INFO Epoch 961/1000  loss=0.7528  bce=0.7453  kd=0.0037  ewc=7.5062e-03  patch_acc=0.233  temp=14.91  lr=3.59e-07
# 2026-04-21 13:48:06,539 INFO Epoch 962/1000  loss=0.7471  bce=0.7396  kd=0.0037  ewc=7.5062e-03  patch_acc=0.275  temp=14.91  lr=3.41e-07
# 2026-04-21 13:48:07,519 INFO Epoch 963/1000  loss=0.7560  bce=0.7485  kd=0.0037  ewc=7.5062e-03  patch_acc=0.239  temp=14.91  lr=3.23e-07
# 2026-04-21 13:48:08,281 INFO Epoch 964/1000  loss=0.7284  bce=0.7209  kd=0.0037  ewc=7.5062e-03  patch_acc=0.261  temp=14.91  lr=3.05e-07
# 2026-04-21 13:48:09,031 INFO Epoch 965/1000  loss=0.7366  bce=0.7291  kd=0.0037  ewc=7.5062e-03  patch_acc=0.253  temp=14.91  lr=2.88e-07
# 2026-04-21 13:48:09,163 INFO   -> val_loss=0.7397  val_patch_acc=0.209
# 2026-04-21 13:48:10,446 INFO Epoch 966/1000  loss=0.7469  bce=0.7393  kd=0.0037  ewc=7.5062e-03  patch_acc=0.236  temp=14.91  lr=2.71e-07
# 2026-04-21 13:48:11,183 INFO Epoch 967/1000  loss=0.7391  bce=0.7316  kd=0.0037  ewc=7.5062e-03  patch_acc=0.241  temp=14.91  lr=2.55e-07
# 2026-04-21 13:48:11,949 INFO Epoch 968/1000  loss=0.7495  bce=0.7420  kd=0.0037  ewc=7.5062e-03  patch_acc=0.250  temp=14.91  lr=2.39e-07
# 2026-04-21 13:48:12,700 INFO Epoch 969/1000  loss=0.7264  bce=0.7189  kd=0.0037  ewc=7.5062e-03  patch_acc=0.274  temp=14.91  lr=2.24e-07
# 2026-04-21 13:48:13,462 INFO Epoch 970/1000  loss=0.7730  bce=0.7655  kd=0.0037  ewc=7.5062e-03  patch_acc=0.237  temp=14.91  lr=2.09e-07
# 2026-04-21 13:48:13,597 INFO   -> val_loss=0.7398  val_patch_acc=0.209
# 2026-04-21 13:48:14,688 INFO Epoch 971/1000  loss=0.7305  bce=0.7230  kd=0.0037  ewc=7.5062e-03  patch_acc=0.270  temp=14.91  lr=1.95e-07
# 2026-04-21 13:48:15,428 INFO Epoch 972/1000  loss=0.7560  bce=0.7485  kd=0.0037  ewc=7.5062e-03  patch_acc=0.218  temp=14.91  lr=1.82e-07
# 2026-04-21 13:48:16,188 INFO Epoch 973/1000  loss=0.7473  bce=0.7398  kd=0.0037  ewc=7.5062e-03  patch_acc=0.225  temp=14.91  lr=1.68e-07
# 2026-04-21 13:48:16,931 INFO Epoch 974/1000  loss=0.7266  bce=0.7191  kd=0.0037  ewc=7.5062e-03  patch_acc=0.280  temp=14.91  lr=1.56e-07
# 2026-04-21 13:48:17,682 INFO Epoch 975/1000  loss=0.7326  bce=0.7251  kd=0.0037  ewc=7.5062e-03  patch_acc=0.217  temp=14.91  lr=1.43e-07
# 2026-04-21 13:48:17,811 INFO   -> val_loss=0.7398  val_patch_acc=0.209
# 2026-04-21 13:48:19,117 INFO Epoch 976/1000  loss=0.7623  bce=0.7547  kd=0.0037  ewc=7.5062e-03  patch_acc=0.242  temp=14.91  lr=1.32e-07
# 2026-04-21 13:48:19,863 INFO Epoch 977/1000  loss=0.7361  bce=0.7286  kd=0.0037  ewc=7.5062e-03  patch_acc=0.246  temp=14.91  lr=1.21e-07
# 2026-04-21 13:48:20,606 INFO Epoch 978/1000  loss=0.7362  bce=0.7287  kd=0.0037  ewc=7.5062e-03  patch_acc=0.248  temp=14.91  lr=1.10e-07
# 2026-04-21 13:48:21,355 INFO Epoch 979/1000  loss=0.7632  bce=0.7557  kd=0.0037  ewc=7.5062e-03  patch_acc=0.247  temp=14.91  lr=9.97e-08
# 2026-04-21 13:48:22,125 INFO Epoch 980/1000  loss=0.7347  bce=0.7272  kd=0.0037  ewc=7.5062e-03  patch_acc=0.262  temp=14.91  lr=8.99e-08
# 2026-04-21 13:48:22,256 INFO   -> val_loss=0.7397  val_patch_acc=0.209
# 2026-04-21 13:48:23,310 INFO Epoch 981/1000  loss=0.7365  bce=0.7290  kd=0.0037  ewc=7.5062e-03  patch_acc=0.248  temp=14.91  lr=8.07e-08
# 2026-04-21 13:48:24,052 INFO Epoch 982/1000  loss=0.7347  bce=0.7272  kd=0.0037  ewc=7.5062e-03  patch_acc=0.265  temp=14.91  lr=7.20e-08
# 2026-04-21 13:48:25,056 INFO Epoch 983/1000  loss=0.7468  bce=0.7393  kd=0.0037  ewc=7.5062e-03  patch_acc=0.262  temp=14.91  lr=6.38e-08
# 2026-04-21 13:48:25,814 INFO Epoch 984/1000  loss=0.7679  bce=0.7604  kd=0.0037  ewc=7.5062e-03  patch_acc=0.227  temp=14.91  lr=5.61e-08
# 2026-04-21 13:48:26,562 INFO Epoch 985/1000  loss=0.7342  bce=0.7267  kd=0.0037  ewc=7.5062e-03  patch_acc=0.254  temp=14.91  lr=4.88e-08
# 2026-04-21 13:48:26,693 INFO   -> val_loss=0.7396  val_patch_acc=0.207
# 2026-04-21 13:48:27,987 INFO Epoch 986/1000  loss=0.7494  bce=0.7419  kd=0.0037  ewc=7.5062e-03  patch_acc=0.259  temp=14.91  lr=4.21e-08
# 2026-04-21 13:48:28,731 INFO Epoch 987/1000  loss=0.7497  bce=0.7422  kd=0.0037  ewc=7.5062e-03  patch_acc=0.248  temp=14.91  lr=3.59e-08
# 2026-04-21 13:48:29,482 INFO Epoch 988/1000  loss=0.7491  bce=0.7415  kd=0.0037  ewc=7.5062e-03  patch_acc=0.269  temp=14.91  lr=3.02e-08
# 2026-04-21 13:48:30,226 INFO Epoch 989/1000  loss=0.7351  bce=0.7276  kd=0.0037  ewc=7.5062e-03  patch_acc=0.246  temp=14.91  lr=2.49e-08
# 2026-04-21 13:48:30,993 INFO Epoch 990/1000  loss=0.7349  bce=0.7273  kd=0.0037  ewc=7.5062e-03  patch_acc=0.248  temp=14.91  lr=2.02e-08
# 2026-04-21 13:48:31,122 INFO   -> val_loss=0.7396  val_patch_acc=0.207
# 2026-04-21 13:48:32,171 INFO Epoch 991/1000  loss=0.7347  bce=0.7272  kd=0.0037  ewc=7.5062e-03  patch_acc=0.262  temp=14.91  lr=1.59e-08
# 2026-04-21 13:48:32,921 INFO Epoch 992/1000  loss=0.7609  bce=0.7534  kd=0.0037  ewc=7.5062e-03  patch_acc=0.227  temp=14.91  lr=1.22e-08
# 2026-04-21 13:48:33,915 INFO Epoch 993/1000  loss=0.7515  bce=0.7440  kd=0.0037  ewc=7.5062e-03  patch_acc=0.221  temp=14.91  lr=8.97e-09
# 2026-04-21 13:48:34,661 INFO Epoch 994/1000  loss=0.7516  bce=0.7441  kd=0.0037  ewc=7.5062e-03  patch_acc=0.221  temp=14.91  lr=6.23e-09
# 2026-04-21 13:48:35,412 INFO Epoch 995/1000  loss=0.7377  bce=0.7302  kd=0.0037  ewc=7.5062e-03  patch_acc=0.225  temp=14.91  lr=3.99e-09
# 2026-04-21 13:48:35,541 INFO   -> val_loss=0.7396  val_patch_acc=0.207
# 2026-04-21 13:48:36,828 INFO Epoch 996/1000  loss=0.7437  bce=0.7362  kd=0.0037  ewc=7.5062e-03  patch_acc=0.247  temp=14.91  lr=2.24e-09
# 2026-04-21 13:48:37,597 INFO Epoch 997/1000  loss=0.7181  bce=0.7106  kd=0.0038  ewc=7.5062e-03  patch_acc=0.263  temp=14.91  lr=9.97e-10
# 2026-04-21 13:48:38,354 INFO Epoch 998/1000  loss=0.7231  bce=0.7156  kd=0.0037  ewc=7.5062e-03  patch_acc=0.267  temp=14.91  lr=2.49e-10
# 2026-04-21 13:48:39,116 INFO Epoch 999/1000  loss=0.7484  bce=0.7409  kd=0.0037  ewc=7.5062e-03  patch_acc=0.246  temp=14.91  lr=0.00e+00
# 2026-04-21 13:48:39,892 INFO Epoch 1000/1000  loss=0.7509  bce=0.7434  kd=0.0037  ewc=7.5062e-03  patch_acc=0.235  temp=14.91  lr=2.49e-10
# 2026-04-21 13:48:40,021 INFO   -> val_loss=0.7396  val_patch_acc=0.207
# 2026-04-21 13:48:40,987 INFO Stage 3b 完了。最良チェックポイント: /content/drive/MyDrive/2026研究/ULIP_PointLLM/DentalPatchAligned3D/Phase3_Training_v2/outputs/stage3b/stage3b_best.pt

# %%
# Stage 3b チェックポイント確認
import os, torch

stage3b_best = os.path.join(OUT_3B, 'checkpoints', 'best.pt')
stage3b_final = os.path.join(OUT_3B, 'stage3b_best.pt')

assert os.path.exists(stage3b_best), f'best.pt が見つかりません: {stage3b_best}'

ckpt = torch.load(stage3b_best, map_location='cpu', weights_only=False)
print(f'Stage 3b best ckpt epoch: {ckpt["epoch"]}')
val_loss = ckpt.get('val_metrics', {}).get('val_loss', float('nan'))
print(f'Stage 3b best val_loss: {val_loss:.4f}')

# Phase 4 向けにコピー
import shutil
shutil.copy(stage3b_best, stage3b_final)
print(f'Phase 4 入力チェックポイント: {stage3b_final}')
print('Stage 3b 完了 ✓')
# Out:
# Stage 3b best ckpt epoch: 830
# Stage 3b best val_loss: 0.7382
# Phase 4 入力チェックポイント: /content/drive/MyDrive/2026研究/ULIP_PointLLM/DentalPatchAligned3D/Phase3_Training_v2/outputs/stage3b/stage3b_best.pt
# Stage 3b 完了 ✓

# %% [markdown]
# ## Step 11 — 学習曲線の可視化

# %%
import re
import matplotlib.pyplot as plt

def parse_log(log_path: str) -> dict:
    """train.log から loss 系列を抽出する。"""
    epochs, losses, val_losses = [], [], []
    ep_pat   = re.compile(r'Epoch\s+(\d+)/\d+.*loss=([\d.]+)')
    val_pat  = re.compile(r'val_loss=([\d.]+)')
    with open(log_path, 'r', encoding='utf-8') as f:
        for line in f:
            m = ep_pat.search(line)
            if m:
                epochs.append(int(m.group(1)))
                losses.append(float(m.group(2)))
            m2 = val_pat.search(line)
            if m2:
                val_losses.append((epochs[-1] if epochs else 0, float(m2.group(1))))
    return {'epochs': epochs, 'losses': losses, 'val': val_losses}

fig, axes = plt.subplots(1, 2, figsize=(12, 4))

for ax, (label, out_dir) in zip(axes, [('Stage 3a', OUT_3A), ('Stage 3b', OUT_3B)]):
    log_path = os.path.join(out_dir, 'train.log')
    if not os.path.exists(log_path):
        ax.set_title(f'{label} (ログなし)')
        continue
    d = parse_log(log_path)
    ax.plot(d['epochs'], d['losses'], label='train loss')
    if d['val']:
        ve, vl = zip(*d['val'])
        ax.plot(ve, vl, 'o--', label='val loss')
    ax.set_title(label)
    ax.set_xlabel('Epoch')
    ax.set_ylabel('Loss')
    ax.legend()

plt.tight_layout()
plt.savefig(os.path.join(PHASE3_DIR, 'training_curves.png'), dpi=120)
plt.show()
print('学習曲線を保存: training_curves.png')
# Out:
# 学習曲線を保存: training_curves.png

# %% [markdown]
# ## Step 12 — パッチ‑テキスト類似度の意味的検証
#
# 学習済み Stage 3b モデルを使って、歯科解剖クエリに対するパッチの類似度ヒートマップを確認する。

# %%
import torch, torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
from easydict import EasyDict

from phase3_models.stage3_model import build_stage3_models
from phase3_datasets.dental_dataset import _load_ply, _normalize_unit_sphere, _fps_cpu

# clip_dim=512: BiomedCLIP テキスト次元に合わせた PatchToTextProj (384→512)
cfg_eval = EasyDict(
    trans_dim=384, depth=12, drop_path_rate=0.1, cls_dim=50,
    num_heads=6, group_size=32, num_group=128, encoder_dims=256,
    color=False, num_classes=16, clip_dim=512, clip_tau=0.07,
)

student, _, proj, _ = build_stage3_models(
    cfg=cfg_eval, device=torch.device(device), ckpt_path='',
)

eval_ckpt = torch.load(stage3b_best, map_location='cpu', weights_only=False)
student.load_state_dict(eval_ckpt['student'], strict=False)
proj.load_state_dict(eval_ckpt['proj'], strict=False)
student.eval().to(device)
proj.eval().to(device)

# BiomedCLIP を推論用に GPU へ
clip_model.to(device)

print(f'Stage 3b best (epoch {eval_ckpt["epoch"]}) モデルロード OK')
print(f'proj shape: {list(proj.proj.weight.shape)}  (期待: [512, 384])')
# Out:
# [Stage3] Student: 学習可能 1,873,536 / 総 21,858,816 パラメータ  Proj: 197,120
# Stage 3b best (epoch 830) モデルロード OK
# proj shape: [512, 384]  (期待: [512, 384])

# %%
# 代表 1 症例 (Pat 1a_norm) でクエリ検索
pat_id   = list(candidates.keys())[0]
ply_path = Path(PLY_DIR) / f'{pat_id}.ply'

xyz_raw = _load_ply(ply_path)
fps_idx = _fps_cpu(xyz_raw, 2048, seed=42)
xyz     = xyz_raw[fps_idx]
xyz_n, _, _ = _normalize_unit_sphere(xyz)
pts_t   = xyz_n.T.unsqueeze(0).to(device)  # (1, 3, 2048)

# テキストクエリ
text_queries = [
    'left mandibular condyle',
    'right coronoid process',
    'left gonial angle',
    'midline mandible body',
    'right mandible body',
    'inferior border of mandible',
    'left ramus of mandible',
]

# BiomedCLIP でテキストエンコード (encode_texts は Step 6 で定義済み)
with torch.no_grad():
    text_feats = encode_texts(text_queries)      # (T, 512)
    patch_emb, patch_centers, _ = student.forward_patches(pts_t)
    patch_feat = proj(patch_emb)                 # (1, G, 512)

sim     = (patch_feat[0] @ text_feats.T).cpu().numpy()   # (G, T)
centers = patch_centers[0].T.cpu().numpy()                # (G, 3)

# 可視化
fig, axes = plt.subplots(1, len(text_queries), figsize=(3 * len(text_queries), 3))
xyz_np = xyz_n.cpu().numpy()

for i, (ax, q) in enumerate(zip(axes, text_queries)):
    ax.scatter(xyz_np[:, 0], xyz_np[:, 2], c='lightgray', s=0.3, alpha=0.5)
    ax.scatter(centers[:, 0], centers[:, 2],
               c=sim[:, i], cmap='coolwarm', s=20,
               vmin=sim[:, i].min(), vmax=sim[:, i].max())
    ax.set_title(q, fontsize=7)
    ax.axis('off')

plt.suptitle(f'{pat_id} — パッチ‑テキスト類似度 [BiomedCLIP, clip_dim=512]', y=1.02)
plt.tight_layout()
plt.savefig(os.path.join(PHASE3_DIR, 'patch_text_heatmap.png'), dpi=120, bbox_inches='tight')
plt.show()
print('ヒートマップ保存: patch_text_heatmap.png')
# Out:
# /tmp/ipykernel_1333/2086878378.py:44: UserWarning: Glyph 12497 (\N{KATAKANA LETTER PA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_1333/2086878378.py:44: UserWarning: Glyph 12483 (\N{KATAKANA LETTER SMALL TU}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_1333/2086878378.py:44: UserWarning: Glyph 12481 (\N{KATAKANA LETTER TI}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_1333/2086878378.py:44: UserWarning: Glyph 12486 (\N{KATAKANA LETTER TE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_1333/2086878378.py:44: UserWarning: Glyph 12461 (\N{KATAKANA LETTER KI}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_1333/2086878378.py:44: UserWarning: Glyph 12473 (\N{KATAKANA LETTER SU}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_1333/2086878378.py:44: UserWarning: Glyph 12488 (\N{KATAKANA LETTER TO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_1333/2086878378.py:44: UserWarning: Glyph 39006 (\N{CJK UNIFIED IDEOGRAPH-985E}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_1333/2086878378.py:44: UserWarning: Glyph 20284 (\N{CJK UNIFIED IDEOGRAPH-4F3C}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_1333/2086878378.py:44: UserWarning: Glyph 24230 (\N{CJK UNIFIED IDEOGRAPH-5EA6}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_1333/2086878378.py:45: UserWarning: Glyph 12497 (\N{KATAKANA LETTER PA}) missing from font(s) DejaVu Sans.
#   plt.savefig(os.path.join(PHASE3_DIR, 'patch_text_heatmap.png'), dpi=120, bbox_inches='tight')
# /tmp/ipykernel_1333/2086878378.py:45: UserWarning: Glyph 12483 (\N{KATAKANA LETTER SMALL TU}) missing from font(s) DejaVu Sans.
#   plt.savefig(os.path.join(PHASE3_DIR, 'patch_text_heatmap.png'), dpi=120, bbox_inches='tight')
# /tmp/ipykernel_1333/2086878378.py:45: UserWarning: Glyph 12481 (\N{KATAKANA LETTER TI}) missing from font(s) DejaVu Sans.
#   plt.savefig(os.path.join(PHASE3_DIR, 'patch_text_heatmap.png'), dpi=120, bbox_inches='tight')
# /tmp/ipykernel_1333/2086878378.py:45: UserWarning: Glyph 12486 (\N{KATAKANA LETTER TE}) missing from font(s) DejaVu Sans.
#   plt.savefig(os.path.join(PHASE3_DIR, 'patch_text_heatmap.png'), dpi=120, bbox_inches='tight')
# /tmp/ipykernel_1333/2086878378.py:45: UserWarning: Glyph 12461 (\N{KATAKANA LETTER KI}) missing from font(s) DejaVu Sans.
#   plt.savefig(os.path.join(PHASE3_DIR, 'patch_text_heatmap.png'), dpi=120, bbox_inches='tight')
# /tmp/ipykernel_1333/2086878378.py:45: UserWarning: Glyph 12473 (\N{KATAKANA LETTER SU}) missing from font(s) DejaVu Sans.
#   plt.savefig(os.path.join(PHASE3_DIR, 'patch_text_heatmap.png'), dpi=120, bbox_inches='tight')
# /tmp/ipykernel_1333/2086878378.py:45: UserWarning: Glyph 12488 (\N{KATAKANA LETTER TO}) missing from font(s) DejaVu Sans.
#   plt.savefig(os.path.join(PHASE3_DIR, 'patch_text_heatmap.png'), dpi=120, bbox_inches='tight')
# /tmp/ipykernel_1333/2086878378.py:45: UserWarning: Glyph 39006 (\N{CJK UNIFIED IDEOGRAPH-985E}) missing from font(s) DejaVu Sans.
#   plt.savefig(os.path.join(PHASE3_DIR, 'patch_text_heatmap.png'), dpi=120, bbox_inches='tight')
# /tmp/ipykernel_1333/2086878378.py:45: UserWarning: Glyph 20284 (\N{CJK UNIFIED IDEOGRAPH-4F3C}) missing from font(s) DejaVu Sans.
#   plt.savefig(os.path.join(PHASE3_DIR, 'patch_text_heatmap.png'), dpi=120, bbox_inches='tight')
# /tmp/ipykernel_1333/2086878378.py:45: UserWarning: Glyph 24230 (\N{CJK UNIFIED IDEOGRAPH-5EA6}) missing from font(s) DejaVu Sans.
#   plt.savefig(os.path.join(PHASE3_DIR, 'patch_text_heatmap.png'), dpi=120, bbox_inches='tight')
# ヒートマップ保存: patch_text_heatmap.png

# %%
import numpy as np
import matplotlib.pyplot as plt
import imageio.v2 as imageio
import io, os

def rotate_z(xyz: np.ndarray, theta_deg: float) -> np.ndarray:
    """点群を z 軸周りに theta_deg 度回転 (右手系)"""
    theta = np.radians(theta_deg)
    c, s = np.cos(theta), np.sin(theta)
    R = np.array([[c, -s, 0], [s, c, 0], [0, 0, 1]], dtype=np.float32)
    return xyz @ R.T

DEGREES_PER_FRAME = 10
N_FRAMES          = 360 // DEGREES_PER_FRAME
FPS               = 8
GIF_DIR           = PHASE3_DIR

os.makedirs(GIF_DIR, exist_ok=True)

print(f'GIF 生成開始: {len(text_queries)} クエリ × {N_FRAMES} フレーム')

for qi, query in enumerate(text_queries):
    sim_q = sim[:, qi]
    vmin, vmax = float(sim_q.min()), float(sim_q.max())

    frames = []
    for angle in range(0, 360, DEGREES_PER_FRAME):
        xyz_rot     = rotate_z(xyz_np, angle)
        centers_rot = rotate_z(centers, angle)

        fig, ax = plt.subplots(figsize=(4, 4), facecolor='white')
        ax.scatter(xyz_rot[:, 0], xyz_rot[:, 2],
                   c='lightgray', s=0.5, alpha=0.4, linewidths=0)
        sc = ax.scatter(centers_rot[:, 0], centers_rot[:, 2],
                        c=sim_q, cmap='coolwarm', s=25,
                        vmin=vmin, vmax=vmax, linewidths=0)
        plt.colorbar(sc, ax=ax, fraction=0.04, pad=0.02)
        ax.set_title(f'{query}\n{angle:3d}°', fontsize=7, pad=3)
        ax.set_xlim(-1.2, 1.2)
        ax.set_ylim(-1.2, 1.2)
        ax.set_aspect('equal')
        ax.axis('off')
        plt.tight_layout(pad=0.5)

        buf = io.BytesIO()
        plt.savefig(buf, format='png', dpi=90, bbox_inches='tight')
        buf.seek(0)
        frames.append(imageio.imread(buf))
        plt.close(fig)

    h = min(f.shape[0] for f in frames)
    w = min(f.shape[1] for f in frames)
    frames = [f[:h, :w] for f in frames]

    safe_name = query.replace(' ', '_').replace('/', '-')[:40]
    gif_path  = os.path.join(GIF_DIR, f'heatmap_{qi:02d}_{safe_name}.gif')
    imageio.mimsave(gif_path, frames, fps=FPS, loop=0)
    print(f'  [{qi+1}/{len(text_queries)}] 保存: {gif_path}')

print(f'\n完了。{len(text_queries)} 件の GIF を {GIF_DIR} に保存しました。')
# Out:
# GIF 生成開始: 7 クエリ × 36 フレーム
#   [1/7] 保存: /content/drive/MyDrive/2026研究/ULIP_PointLLM/DentalPatchAligned3D/Phase3_Training_v2/heatmap_00_left_mandibular_condyle.gif
#   [2/7] 保存: /content/drive/MyDrive/2026研究/ULIP_PointLLM/DentalPatchAligned3D/Phase3_Training_v2/heatmap_01_right_coronoid_process.gif
#   [3/7] 保存: /content/drive/MyDrive/2026研究/ULIP_PointLLM/DentalPatchAligned3D/Phase3_Training_v2/heatmap_02_left_gonial_angle.gif
#   [4/7] 保存: /content/drive/MyDrive/2026研究/ULIP_PointLLM/DentalPatchAligned3D/Phase3_Training_v2/heatmap_03_midline_mandible_body.gif
#   [5/7] 保存: /content/drive/MyDrive/2026研究/ULIP_PointLLM/DentalPatchAligned3D/Phase3_Training_v2/heatmap_04_right_mandible_body.gif
#   [6/7] 保存: /content/drive/MyDrive/2026研究/ULIP_PointLLM/DentalPatchAligned3D/Phase3_Training_v2/heatmap_05_inferior_border_of_mandible.gif
#   [7/7] 保存: /content/drive/MyDrive/2026研究/ULIP_PointLLM/DentalPatchAligned3D/Phase3_Training_v2/heatmap_06_left_ramus_of_mandible.gif
#
# 完了。7 件の GIF を /content/drive/MyDrive/2026研究/ULIP_PointLLM/DentalPatchAligned3D/Phase3_Training_v2 に保存しました。

# %% [markdown]
# ## Step 13 — 結果確認 & Phase 4 への引き渡し
#
# | チェック項目 | 期待値 |
# |------------|-------|
# | Stage 3a best val_loss | 学習が進むにつれ低下していること |
# | Stage 3b best val_loss | Stage 3a より低いか同程度 |
# | ヒートマップ | 解剖クエリが対応する部位と高い類似度 |
# | `stage3b_best.pt` | Drive に保存済み |

# %%
import os

PASS = True
checks = [
    ('stage3a_last.pt',               STAGE3A_LAST),
    ('stage3a best.pt',               os.path.join(OUT_3A, 'checkpoints', 'best.pt')),
    ('stage3b best.pt',               stage3b_best),
    ('stage3b_best.pt (Phase4用)',     stage3b_final),
    ('training_curves.png',           os.path.join(PHASE3_DIR, 'training_curves.png')),
    ('patch_text_heatmap.png',        os.path.join(PHASE3_DIR, 'patch_text_heatmap.png')),
]

for name, path in checks:
    ok = os.path.exists(path)
    PASS = PASS and ok
    status = '[OK]' if ok else '[NG]'
    print(f'{status} {name}')
    if ok:
        size_mb = os.path.getsize(path) / 1e6
        print(f'     → {path}  ({size_mb:.1f} MB)')
    else:
        print(f'     → 見つかりません: {path}')

print()
if PASS:
    print('[PASS] Phase 3 完了 → Phase 4 (Attribution) へ進めます')
    print(f'Phase 4 入力チェックポイント: {stage3b_final}')
else:
    print('[FAIL] 一部のファイルが見つかりません。上のセルを再実行してください。')
# Out:
# [OK] stage3a_last.pt
#      → /content/drive/MyDrive/2026研究/ULIP_PointLLM/DentalPatchAligned3D/Phase3_Training_v2/outputs/stage3a/stage3a_last.pt  (88.3 MB)
# [OK] stage3a best.pt
#      → /content/drive/MyDrive/2026研究/ULIP_PointLLM/DentalPatchAligned3D/Phase3_Training_v2/outputs/stage3a/checkpoints/best.pt  (104.9 MB)
# [OK] stage3b best.pt
#      → /content/drive/MyDrive/2026研究/ULIP_PointLLM/DentalPatchAligned3D/Phase3_Training_v2/outputs/stage3b/checkpoints/best.pt  (104.9 MB)
# [OK] stage3b_best.pt (Phase4用)
#      → /content/drive/MyDrive/2026研究/ULIP_PointLLM/DentalPatchAligned3D/Phase3_Training_v2/outputs/stage3b/stage3b_best.pt  (104.9 MB)
# [OK] training_curves.png
#      → /content/drive/MyDrive/2026研究/ULIP_PointLLM/DentalPatchAligned3D/Phase3_Training_v2/training_curves.png  (0.1 MB)
# [OK] patch_text_heatmap.png
#      → /content/drive/MyDrive/2026研究/ULIP_PointLLM/DentalPatchAligned3D/Phase3_Training_v2/patch_text_heatmap.png  (0.2 MB)
#
# [PASS] Phase 3 完了 → Phase 4 (Attribution) へ進めます
# Phase 4 入力チェックポイント: /content/drive/MyDrive/2026研究/ULIP_PointLLM/DentalPatchAligned3D/Phase3_Training_v2/outputs/stage3b/stage3b_best.pt

# %% [markdown]
# ## トラブルシューティング
#
# | 症状 | 原因 | 対処 |
# |------|------|------|
# | Step 6 で `AssertionError: 次元不一致` | BiomedCLIP モデル名が異なる | `BIOMEDCLIP_HUB` を確認: `hf-hub:microsoft/BiomedCLIP-PubMedBERT_256-vit_base_patch16_224` |
# | BiomedCLIP ダウンロード失敗 | HF Token 未設定 | Colab Secrets に `HF_TOKEN` を設定して再実行 |
# | `RuntimeError: 有効な PLY が見つかりません` | PLY_DIR パスの不一致 | `PLY_DIR` の内容を確認 |
# | `assert len(matched) > 0` 失敗 | JSON キーと PLY ファイル名の不一致 | candidates.json のキー名を確認 |
# | `CUDA out of memory` | VRAM 不足 | Stage 3a: `batch_size: 2`、Stage 3b: `batch_size: 16` に変更して YAML 再生成 |
# | `ModuleNotFoundError: patchalign3d` | Step 4 のパス設定不足 | Step 4 のセルを再実行 |
# | `size mismatch for proj.weight` | clip_dim の不一致 | Step 12 の `cfg_eval` で `clip_dim=512` になっているか確認 |
# | Stage 3a val_loss が下がらない | 学習率の調整 | `lr` を `5e-6` に下げる |
# | EWC Fisher 計算が遅い | Fisher バッチ数が多い | `ewc_fisher_batches: 20` に変更 |
# | open_clip download timeout | ネットワーク問題 | セルを再実行 (キャッシュから再開される) |
